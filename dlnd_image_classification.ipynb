# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np
from sklearn import preprocessing

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
labelsHotEncode = False

def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    a = 0.1
    b = 0.9
    grayscale_min = 0
    grayscale_max = 255
    return a + ( ( (x - grayscale_min)*(b - a) )/( grayscale_max - grayscale_min ) )


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    global labelsHotEncode
    
    if not labelsHotEncode:
        labelsHotEncode = preprocessing.LabelBinarizer().fit(x)

    return labelsHotEncode.transform(x)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=[None, *image_shape], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=[None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    # print(conv_num_outputs)
    # print(conv_ksize)
    # print(conv_strides)
    # print(pool_ksize)
    # print(pool_strides)
    tshape = x_tensor.get_shape()
    padding='SAME'
    F_W = tf.Variable(tf.random_normal((*conv_ksize, tshape[3].value, conv_num_outputs), mean=0.0, stddev=0.1, dtype=tf.float32))
    F_b = tf.Variable(tf.zeros(conv_num_outputs))
    x = tf.nn.conv2d(x_tensor, F_W, strides=[1, *conv_strides, 1], padding=padding)
    x = tf.nn.bias_add(x, F_b)
    x = tf.nn.relu(x) # nonlinear activation
    x = tf.nn.max_pool(x, [1, *pool_ksize, 1], [1, *pool_strides, 1], padding)
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    b, w, h, d = x_tensor.get_shape().as_list()
    fsize = w * h *d
    # print(fsize)
    return tf.reshape(x_tensor, [-1, fsize])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    i, bs = x_tensor.get_shape().as_list()
    W = tf.Variable(tf.random_normal((bs, num_outputs), mean=0.0, stddev=0.1, dtype=tf.float32))
    b = tf.Variable(tf.zeros(num_outputs))
    x = tf.add(tf.matmul(x_tensor, W), b)
    return tf.nn.relu(x)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    i, bs = x_tensor.get_shape().as_list()
    W = tf.Variable(tf.random_normal((bs, num_outputs), mean=0.0, stddev=0.1, dtype=tf.float32))
    b = tf.Variable(tf.zeros(num_outputs))
    return tf.add(tf.matmul(x_tensor, W), b)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    
    conv_num_outputs=10
    conv_ksize=(2, 2)
    conv_strides=(4, 4)
    pool_ksize=(2, 2)
    pool_strides=(2, 2)

    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    net = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    # net = conv2d_maxpool(net, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    # net = conv2d_maxpool(net, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    net = flatten(net)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    net = fully_conn(net, conv_num_outputs)
    net = tf.nn.dropout (net, keep_prob)
    net = fully_conn(net, conv_num_outputs)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    net = output(net, conv_num_outputs)
    
    # TODO: return output
    return net


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    los = session.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    acc = session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.0})
    print("Loss => ", los, " | Accuracy => ", acc)

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 200
batch_size = 512
keep_probability = 0.75

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss =>  2.3016  | Accuracy =>  0.1298
# Epoch  2, CIFAR-10 Batch 1:  Loss =>  2.29854  | Accuracy =>  0.1768
# Epoch  3, CIFAR-10 Batch 1:  Loss =>  2.28951  | Accuracy =>  0.1674
# Epoch  4, CIFAR-10 Batch 1:  Loss =>  2.26782  | Accuracy =>  0.1798
# Epoch  5, CIFAR-10 Batch 1:  Loss =>  2.22949  | Accuracy =>  0.1898
# Epoch  6, CIFAR-10 Batch 1:  Loss =>  2.19123  | Accuracy =>  0.188
# Epoch  7, CIFAR-10 Batch 1:  Loss =>  2.17215  | Accuracy =>  0.1926
# Epoch  8, CIFAR-10 Batch 1:  Loss =>  2.14663  | Accuracy =>  0.2052
# Epoch  9, CIFAR-10 Batch 1:  Loss =>  2.13914  | Accuracy =>  0.2202
# Epoch 10, CIFAR-10 Batch 1:  Loss =>  2.12674  | Accuracy =>  0.2276
# Epoch 11, CIFAR-10 Batch 1:  Loss =>  2.1238  | Accuracy =>  0.2256
# Epoch 12, CIFAR-10 Batch 1:  Loss =>  2.11161  | Accuracy =>  0.2234
# Epoch 13, CIFAR-10 Batch 1:  Loss =>  2.10675  | Accuracy =>  0.2294
# Epoch 14, CIFAR-10 Batch 1:  Loss =>  2.10211  | Accuracy =>  0.2296
# Epoch 15, CIFAR-10 Batch 1:  Loss =>  2.09778  | Accuracy =>  0.2328
# Epoch 16, CIFAR-10 Batch 1:  Loss =>  2.09376  | Accuracy =>  0.2314
# Epoch 17, CIFAR-10 Batch 1:  Loss =>  2.09023  | Accuracy =>  0.236
# Epoch 18, CIFAR-10 Batch 1:  Loss =>  2.08799  | Accuracy =>  0.2358
# Epoch 19, CIFAR-10 Batch 1:  Loss =>  2.0807  | Accuracy =>  0.2384
# Epoch 20, CIFAR-10 Batch 1:  Loss =>  2.07548  | Accuracy =>  0.2366
# Epoch 21, CIFAR-10 Batch 1:  Loss =>  2.07845  | Accuracy =>  0.2374
# Epoch 22, CIFAR-10 Batch 1:  Loss =>  2.07032  | Accuracy =>  0.2444
# Epoch 23, CIFAR-10 Batch 1:  Loss =>  2.07253  | Accuracy =>  0.241
# Epoch 24, CIFAR-10 Batch 1:  Loss =>  2.06981  | Accuracy =>  0.2412
# Epoch 25, CIFAR-10 Batch 1:  Loss =>  2.06373  | Accuracy =>  0.2448
# Epoch 26, CIFAR-10 Batch 1:  Loss =>  2.05817  | Accuracy =>  0.2452
# Epoch 27, CIFAR-10 Batch 1:  Loss =>  2.05864  | Accuracy =>  0.2494
# Epoch 28, CIFAR-10 Batch 1:  Loss =>  2.0544  | Accuracy =>  0.2474
# Epoch 29, CIFAR-10 Batch 1:  Loss =>  2.0514  | Accuracy =>  0.2474
# Epoch 30, CIFAR-10 Batch 1:  Loss =>  2.04952  | Accuracy =>  0.2498
# Epoch 31, CIFAR-10 Batch 1:  Loss =>  2.04796  | Accuracy =>  0.2492
# Epoch 32, CIFAR-10 Batch 1:  Loss =>  2.04259  | Accuracy =>  0.2484
# Epoch 33, CIFAR-10 Batch 1:  Loss =>  2.04306  | Accuracy =>  0.2512
# Epoch 34, CIFAR-10 Batch 1:  Loss =>  2.03809  | Accuracy =>  0.253
# Epoch 35, CIFAR-10 Batch 1:  Loss =>  2.04053  | Accuracy =>  0.2552
# Epoch 36, CIFAR-10 Batch 1:  Loss =>  2.03885  | Accuracy =>  0.253
# Epoch 37, CIFAR-10 Batch 1:  Loss =>  2.03818  | Accuracy =>  0.257
# Epoch 38, CIFAR-10 Batch 1:  Loss =>  2.03519  | Accuracy =>  0.2562
# Epoch 39, CIFAR-10 Batch 1:  Loss =>  2.0321  | Accuracy =>  0.2572
# Epoch 40, CIFAR-10 Batch 1:  Loss =>  2.03398  | Accuracy =>  0.2606
# Epoch 41, CIFAR-10 Batch 1:  Loss =>  2.03009  | Accuracy =>  0.2616
# Epoch 42, CIFAR-10 Batch 1:  Loss =>  2.02972  | Accuracy =>  0.2604
# Epoch 43, CIFAR-10 Batch 1:  Loss =>  2.02602  | Accuracy =>  0.2608
# Epoch 44, CIFAR-10 Batch 1:  Loss =>  2.0332  | Accuracy =>  0.264
# Epoch 45, CIFAR-10 Batch 1:  Loss =>  2.02482  | Accuracy =>  0.2642
# Epoch 46, CIFAR-10 Batch 1:  Loss =>  2.02203  | Accuracy =>  0.2652
# Epoch 47, CIFAR-10 Batch 1:  Loss =>  2.02216  | Accuracy =>  0.2626
# Epoch 48, CIFAR-10 Batch 1:  Loss =>  2.02256  | Accuracy =>  0.2634
# Epoch 49, CIFAR-10 Batch 1:  Loss =>  2.01609  | Accuracy =>  0.2622
# Epoch 50, CIFAR-10 Batch 1:  Loss =>  2.0181  | Accuracy =>  0.265
# Epoch 51, CIFAR-10 Batch 1:  Loss =>  2.01378  | Accuracy =>  0.267
# Epoch 52, CIFAR-10 Batch 1:  Loss =>  2.01217  | Accuracy =>  0.2656
# Epoch 53, CIFAR-10 Batch 1:  Loss =>  2.01373  | Accuracy =>  0.2678
# Epoch 54, CIFAR-10 Batch 1:  Loss =>  2.00913  | Accuracy =>  0.266
# Epoch 55, CIFAR-10 Batch 1:  Loss =>  2.01595  | Accuracy =>  0.2658
# Epoch 56, CIFAR-10 Batch 1:  Loss =>  2.00867  | Accuracy =>  0.2654
# Epoch 57, CIFAR-10 Batch 1:  Loss =>  2.01577  | Accuracy =>  0.2686
# Epoch 58, CIFAR-10 Batch 1:  Loss =>  2.00627  | Accuracy =>  0.271
# Epoch 59, CIFAR-10 Batch 1:  Loss =>  2.00499  | Accuracy =>  0.2722
# Epoch 60, CIFAR-10 Batch 1:  Loss =>  2.00667  | Accuracy =>  0.2714
# Epoch 61, CIFAR-10 Batch 1:  Loss =>  2.0002  | Accuracy =>  0.2716
# Epoch 62, CIFAR-10 Batch 1:  Loss =>  1.99841  | Accuracy =>  0.2736
# Epoch 63, CIFAR-10 Batch 1:  Loss =>  1.99583  | Accuracy =>  0.273
# Epoch 64, CIFAR-10 Batch 1:  Loss =>  1.99836  | Accuracy =>  0.2722
# Epoch 65, CIFAR-10 Batch 1:  Loss =>  2.0018  | Accuracy =>  0.2722
# Epoch 66, CIFAR-10 Batch 1:  Loss =>  1.99618  | Accuracy =>  0.276
# Epoch 67, CIFAR-10 Batch 1:  Loss =>  1.99627  | Accuracy =>  0.2762
# Epoch 68, CIFAR-10 Batch 1:  Loss =>  1.99435  | Accuracy =>  0.2796
# Epoch 69, CIFAR-10 Batch 1:  Loss =>  1.9998  | Accuracy =>  0.2758
# Epoch 70, CIFAR-10 Batch 1:  Loss =>  1.99709  | Accuracy =>  0.276
# Epoch 71, CIFAR-10 Batch 1:  Loss =>  1.98632  | Accuracy =>  0.2806
# Epoch 72, CIFAR-10 Batch 1:  Loss =>  1.99635  | Accuracy =>  0.2788
# Epoch 73, CIFAR-10 Batch 1:  Loss =>  1.98961  | Accuracy =>  0.2794
# Epoch 74, CIFAR-10 Batch 1:  Loss =>  1.98321  | Accuracy =>  0.2816
# Epoch 75, CIFAR-10 Batch 1:  Loss =>  1.99145  | Accuracy =>  0.2832
# Epoch 76, CIFAR-10 Batch 1:  Loss =>  1.98481  | Accuracy =>  0.28
# Epoch 77, CIFAR-10 Batch 1:  Loss =>  1.98962  | Accuracy =>  0.2834
# Epoch 78, CIFAR-10 Batch 1:  Loss =>  1.9836  | Accuracy =>  0.286
# Epoch 79, CIFAR-10 Batch 1:  Loss =>  1.98178  | Accuracy =>  0.2854
# Epoch 80, CIFAR-10 Batch 1:  Loss =>  1.97735  | Accuracy =>  0.2882
# Epoch 81, CIFAR-10 Batch 1:  Loss =>  1.98562  | Accuracy =>  0.2874
# Epoch 82, CIFAR-10 Batch 1:  Loss =>  1.97725  | Accuracy =>  0.287
# Epoch 83, CIFAR-10 Batch 1:  Loss =>  1.98256  | Accuracy =>  0.2886
# Epoch 84, CIFAR-10 Batch 1:  Loss =>  1.97764  | Accuracy =>  0.293
# Epoch 85, CIFAR-10 Batch 1:  Loss =>  1.973  | Accuracy =>  0.2952
# Epoch 86, CIFAR-10 Batch 1:  Loss =>  1.97369  | Accuracy =>  0.298
# Epoch 87, CIFAR-10 Batch 1:  Loss =>  1.97389  | Accuracy =>  0.2962
# Epoch 88, CIFAR-10 Batch 1:  Loss =>  1.96745  | Accuracy =>  0.294
# Epoch 89, CIFAR-10 Batch 1:  Loss =>  1.96807  | Accuracy =>  0.298
# Epoch 90, CIFAR-10 Batch 1:  Loss =>  1.96278  | Accuracy =>  0.2986
# Epoch 91, CIFAR-10 Batch 1:  Loss =>  1.96385  | Accuracy =>  0.2986
# Epoch 92, CIFAR-10 Batch 1:  Loss =>  1.96313  | Accuracy =>  0.2996
# Epoch 93, CIFAR-10 Batch 1:  Loss =>  1.96287  | Accuracy =>  0.3022
# Epoch 94, CIFAR-10 Batch 1:  Loss =>  1.95931  | Accuracy =>  0.3012
# Epoch 95, CIFAR-10 Batch 1:  Loss =>  1.95586  | Accuracy =>  0.3036
# Epoch 96, CIFAR-10 Batch 1:  Loss =>  1.95135  | Accuracy =>  0.3054
# Epoch 97, CIFAR-10 Batch 1:  Loss =>  1.95138  | Accuracy =>  0.3096
# Epoch 98, CIFAR-10 Batch 1:  Loss =>  1.95276  | Accuracy =>  0.3078
# Epoch 99, CIFAR-10 Batch 1:  Loss =>  1.94663  | Accuracy =>  0.3078
# Epoch 100, CIFAR-10 Batch 1:  Loss =>  1.95394  | Accuracy =>  0.312
# Epoch 101, CIFAR-10 Batch 1:  Loss =>  1.94217  | Accuracy =>  0.314
# Epoch 102, CIFAR-10 Batch 1:  Loss =>  1.93472  | Accuracy =>  0.3142
# Epoch 103, CIFAR-10 Batch 1:  Loss =>  1.94297  | Accuracy =>  0.3152
# Epoch 104, CIFAR-10 Batch 1:  Loss =>  1.93511  | Accuracy =>  0.3148
# Epoch 105, CIFAR-10 Batch 1:  Loss =>  1.93565  | Accuracy =>  0.3186
# Epoch 106, CIFAR-10 Batch 1:  Loss =>  1.93759  | Accuracy =>  0.3208
# Epoch 107, CIFAR-10 Batch 1:  Loss =>  1.92547  | Accuracy =>  0.3176
# Epoch 108, CIFAR-10 Batch 1:  Loss =>  1.9293  | Accuracy =>  0.3184
# Epoch 109, CIFAR-10 Batch 1:  Loss =>  1.9294  | Accuracy =>  0.3224
# Epoch 110, CIFAR-10 Batch 1:  Loss =>  1.92466  | Accuracy =>  0.32
# Epoch 111, CIFAR-10 Batch 1:  Loss =>  1.91376  | Accuracy =>  0.3186
# Epoch 112, CIFAR-10 Batch 1:  Loss =>  1.91815  | Accuracy =>  0.3196
# Epoch 113, CIFAR-10 Batch 1:  Loss =>  1.91982  | Accuracy =>  0.3238
# Epoch 114, CIFAR-10 Batch 1:  Loss =>  1.92032  | Accuracy =>  0.3228
# Epoch 115, CIFAR-10 Batch 1:  Loss =>  1.90844  | Accuracy =>  0.3266
# Epoch 116, CIFAR-10 Batch 1:  Loss =>  1.907  | Accuracy =>  0.327
# Epoch 117, CIFAR-10 Batch 1:  Loss =>  1.90955  | Accuracy =>  0.3272
# Epoch 118, CIFAR-10 Batch 1:  Loss =>  1.90702  | Accuracy =>  0.326
# Epoch 119, CIFAR-10 Batch 1:  Loss =>  1.90392  | Accuracy =>  0.3288
# Epoch 120, CIFAR-10 Batch 1:  Loss =>  1.90109  | Accuracy =>  0.3272
# Epoch 121, CIFAR-10 Batch 1:  Loss =>  1.89331  | Accuracy =>  0.331
# Epoch 122, CIFAR-10 Batch 1:  Loss =>  1.90275  | Accuracy =>  0.3294
# Epoch 123, CIFAR-10 Batch 1:  Loss =>  1.88952  | Accuracy =>  0.3288
# Epoch 124, CIFAR-10 Batch 1:  Loss =>  1.8897  | Accuracy =>  0.3288
# Epoch 125, CIFAR-10 Batch 1:  Loss =>  1.8863  | Accuracy =>  0.3324
# Epoch 126, CIFAR-10 Batch 1:  Loss =>  1.883  | Accuracy =>  0.3322
# Epoch 127, CIFAR-10 Batch 1:  Loss =>  1.87021  | Accuracy =>  0.334
# Epoch 128, CIFAR-10 Batch 1:  Loss =>  1.88506  | Accuracy =>  0.329
# Epoch 129, CIFAR-10 Batch 1:  Loss =>  1.87484  | Accuracy =>  0.3328
# Epoch 130, CIFAR-10 Batch 1:  Loss =>  1.87772  | Accuracy =>  0.3318
# Epoch 131, CIFAR-10 Batch 1:  Loss =>  1.87437  | Accuracy =>  0.336
# Epoch 132, CIFAR-10 Batch 1:  Loss =>  1.86791  | Accuracy =>  0.3366
# Epoch 133, CIFAR-10 Batch 1:  Loss =>  1.86488  | Accuracy =>  0.3352
# Epoch 134, CIFAR-10 Batch 1:  Loss =>  1.86567  | Accuracy =>  0.3354
# Epoch 135, CIFAR-10 Batch 1:  Loss =>  1.87144  | Accuracy =>  0.3348
# Epoch 136, CIFAR-10 Batch 1:  Loss =>  1.85789  | Accuracy =>  0.3418
# Epoch 137, CIFAR-10 Batch 1:  Loss =>  1.86563  | Accuracy =>  0.3388
# Epoch 138, CIFAR-10 Batch 1:  Loss =>  1.87227  | Accuracy =>  0.337
# Epoch 139, CIFAR-10 Batch 1:  Loss =>  1.85659  | Accuracy =>  0.3386
# Epoch 140, CIFAR-10 Batch 1:  Loss =>  1.8596  | Accuracy =>  0.3384
# Epoch 141, CIFAR-10 Batch 1:  Loss =>  1.84868  | Accuracy =>  0.3392
# Epoch 142, CIFAR-10 Batch 1:  Loss =>  1.84596  | Accuracy =>  0.3398
# Epoch 143, CIFAR-10 Batch 1:  Loss =>  1.85261  | Accuracy =>  0.3386
# Epoch 144, CIFAR-10 Batch 1:  Loss =>  1.8382  | Accuracy =>  0.3434
# Epoch 145, CIFAR-10 Batch 1:  Loss =>  1.83814  | Accuracy =>  0.341
# Epoch 146, CIFAR-10 Batch 1:  Loss =>  1.84597  | Accuracy =>  0.3466
# Epoch 147, CIFAR-10 Batch 1:  Loss =>  1.84005  | Accuracy =>  0.3438
# Epoch 148, CIFAR-10 Batch 1:  Loss =>  1.83395  | Accuracy =>  0.3444
# Epoch 149, CIFAR-10 Batch 1:  Loss =>  1.82768  | Accuracy =>  0.3488
# Epoch 150, CIFAR-10 Batch 1:  Loss =>  1.83748  | Accuracy =>  0.3466
# Epoch 151, CIFAR-10 Batch 1:  Loss =>  1.8311  | Accuracy =>  0.343
# Epoch 152, CIFAR-10 Batch 1:  Loss =>  1.82241  | Accuracy =>  0.3476
# Epoch 153, CIFAR-10 Batch 1:  Loss =>  1.82819  | Accuracy =>  0.3506
# Epoch 154, CIFAR-10 Batch 1:  Loss =>  1.82235  | Accuracy =>  0.3466
# Epoch 155, CIFAR-10 Batch 1:  Loss =>  1.82759  | Accuracy =>  0.3482
# Epoch 156, CIFAR-10 Batch 1:  Loss =>  1.82829  | Accuracy =>  0.3494
# Epoch 157, CIFAR-10 Batch 1:  Loss =>  1.82533  | Accuracy =>  0.3502
# Epoch 158, CIFAR-10 Batch 1:  Loss =>  1.81215  | Accuracy =>  0.354
# Epoch 159, CIFAR-10 Batch 1:  Loss =>  1.82369  | Accuracy =>  0.3508
# Epoch 160, CIFAR-10 Batch 1:  Loss =>  1.8159  | Accuracy =>  0.3534
# Epoch 161, CIFAR-10 Batch 1:  Loss =>  1.81483  | Accuracy =>  0.3532
# Epoch 162, CIFAR-10 Batch 1:  Loss =>  1.81483  | Accuracy =>  0.3542
# Epoch 163, CIFAR-10 Batch 1:  Loss =>  1.8093  | Accuracy =>  0.3566
# Epoch 164, CIFAR-10 Batch 1:  Loss =>  1.81239  | Accuracy =>  0.3566
# Epoch 165, CIFAR-10 Batch 1:  Loss =>  1.81135  | Accuracy =>  0.354
# Epoch 166, CIFAR-10 Batch 1:  Loss =>  1.8057  | Accuracy =>  0.358
# Epoch 167, CIFAR-10 Batch 1:  Loss =>  1.80548  | Accuracy =>  0.3538
# Epoch 168, CIFAR-10 Batch 1:  Loss =>  1.80008  | Accuracy =>  0.3586
# Epoch 169, CIFAR-10 Batch 1:  Loss =>  1.79788  | Accuracy =>  0.3596
# Epoch 170, CIFAR-10 Batch 1:  Loss =>  1.7917  | Accuracy =>  0.3578
# Epoch 171, CIFAR-10 Batch 1:  Loss =>  1.79812  | Accuracy =>  0.361
# Epoch 172, CIFAR-10 Batch 1:  Loss =>  1.79668  | Accuracy =>  0.3602
# Epoch 173, CIFAR-10 Batch 1:  Loss =>  1.79656  | Accuracy =>  0.3606
# Epoch 174, CIFAR-10 Batch 1:  Loss =>  1.78811  | Accuracy =>  0.3616
# Epoch 175, CIFAR-10 Batch 1:  Loss =>  1.78457  | Accuracy =>  0.3624
# Epoch 176, CIFAR-10 Batch 1:  Loss =>  1.79091  | Accuracy =>  0.3632
# Epoch 177, CIFAR-10 Batch 1:  Loss =>  1.7831  | Accuracy =>  0.3638
# Epoch 178, CIFAR-10 Batch 1:  Loss =>  1.78697  | Accuracy =>  0.3656
# Epoch 179, CIFAR-10 Batch 1:  Loss =>  1.78634  | Accuracy =>  0.3664
# Epoch 180, CIFAR-10 Batch 1:  Loss =>  1.77936  | Accuracy =>  0.3684
# Epoch 181, CIFAR-10 Batch 1:  Loss =>  1.77661  | Accuracy =>  0.3676
# Epoch 182, CIFAR-10 Batch 1:  Loss =>  1.7804  | Accuracy =>  0.3678
# Epoch 183, CIFAR-10 Batch 1:  Loss =>  1.77634  | Accuracy =>  0.3672
# Epoch 184, CIFAR-10 Batch 1:  Loss =>  1.77399  | Accuracy =>  0.366
# Epoch 185, CIFAR-10 Batch 1:  Loss =>  1.77832  | Accuracy =>  0.3684
# Epoch 186, CIFAR-10 Batch 1:  Loss =>  1.77918  | Accuracy =>  0.366
# Epoch 187, CIFAR-10 Batch 1:  Loss =>  1.78419  | Accuracy =>  0.3646
# Epoch 188, CIFAR-10 Batch 1:  Loss =>  1.7596  | Accuracy =>  0.3692
# Epoch 189, CIFAR-10 Batch 1:  Loss =>  1.77253  | Accuracy =>  0.3664
# Epoch 190, CIFAR-10 Batch 1:  Loss =>  1.76348  | Accuracy =>  0.3704
# Epoch 191, CIFAR-10 Batch 1:  Loss =>  1.76169  | Accuracy =>  0.3718
# Epoch 192, CIFAR-10 Batch 1:  Loss =>  1.77099  | Accuracy =>  0.3696
# Epoch 193, CIFAR-10 Batch 1:  Loss =>  1.75463  | Accuracy =>  0.3746
# Epoch 194, CIFAR-10 Batch 1:  Loss =>  1.76431  | Accuracy =>  0.3686
# Epoch 195, CIFAR-10 Batch 1:  Loss =>  1.75356  | Accuracy =>  0.3768
# Epoch 196, CIFAR-10 Batch 1:  Loss =>  1.755  | Accuracy =>  0.376
# Epoch 197, CIFAR-10 Batch 1:  Loss =>  1.7616  | Accuracy =>  0.3732
# Epoch 198, CIFAR-10 Batch 1:  Loss =>  1.7555  | Accuracy =>  0.3748
# Epoch 199, CIFAR-10 Batch 1:  Loss =>  1.75983  | Accuracy =>  0.3752
# Epoch 200, CIFAR-10 Batch 1:  Loss =>  1.75623  | Accuracy =>  0.3732

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss =>  2.30213  | Accuracy =>  0.098
# Epoch  1, CIFAR-10 Batch 2:  Loss =>  2.30132  | Accuracy =>  0.1452
# Epoch  1, CIFAR-10 Batch 3:  Loss =>  2.29835  | Accuracy =>  0.155
# Epoch  1, CIFAR-10 Batch 4:  Loss =>  2.29253  | Accuracy =>  0.166
# Epoch  1, CIFAR-10 Batch 5:  Loss =>  2.28027  | Accuracy =>  0.178
# Epoch  2, CIFAR-10 Batch 1:  Loss =>  2.24911  | Accuracy =>  0.1942
# Epoch  2, CIFAR-10 Batch 2:  Loss =>  2.18217  | Accuracy =>  0.1966
# Epoch  2, CIFAR-10 Batch 3:  Loss =>  2.14698  | Accuracy =>  0.2028
# Epoch  2, CIFAR-10 Batch 4:  Loss =>  2.08479  | Accuracy =>  0.2252
# Epoch  2, CIFAR-10 Batch 5:  Loss =>  2.07539  | Accuracy =>  0.2318
# Epoch  3, CIFAR-10 Batch 1:  Loss =>  2.11562  | Accuracy =>  0.2288
# Epoch  3, CIFAR-10 Batch 2:  Loss =>  2.04885  | Accuracy =>  0.2316
# Epoch  3, CIFAR-10 Batch 3:  Loss =>  2.03622  | Accuracy =>  0.2394
# Epoch  3, CIFAR-10 Batch 4:  Loss =>  2.00826  | Accuracy =>  0.2452
# Epoch  3, CIFAR-10 Batch 5:  Loss =>  2.03302  | Accuracy =>  0.2472
# Epoch  4, CIFAR-10 Batch 1:  Loss =>  2.08963  | Accuracy =>  0.2472
# Epoch  4, CIFAR-10 Batch 2:  Loss =>  2.01162  | Accuracy =>  0.2426
# Epoch  4, CIFAR-10 Batch 3:  Loss =>  1.99258  | Accuracy =>  0.2528
# Epoch  4, CIFAR-10 Batch 4:  Loss =>  1.9786  | Accuracy =>  0.255
# Epoch  4, CIFAR-10 Batch 5:  Loss =>  2.00819  | Accuracy =>  0.257
# Epoch  5, CIFAR-10 Batch 1:  Loss =>  2.08087  | Accuracy =>  0.2604
# Epoch  5, CIFAR-10 Batch 2:  Loss =>  1.97971  | Accuracy =>  0.2622
# Epoch  5, CIFAR-10 Batch 3:  Loss =>  1.96026  | Accuracy =>  0.267
# Epoch  5, CIFAR-10 Batch 4:  Loss =>  1.9469  | Accuracy =>  0.2652
# Epoch  5, CIFAR-10 Batch 5:  Loss =>  1.98067  | Accuracy =>  0.2656
# Epoch  6, CIFAR-10 Batch 1:  Loss =>  2.04703  | Accuracy =>  0.2706
# Epoch  6, CIFAR-10 Batch 2:  Loss =>  1.94495  | Accuracy =>  0.2718
# Epoch  6, CIFAR-10 Batch 3:  Loss =>  1.92721  | Accuracy =>  0.2742
# Epoch  6, CIFAR-10 Batch 4:  Loss =>  1.92237  | Accuracy =>  0.2724
# Epoch  6, CIFAR-10 Batch 5:  Loss =>  1.95103  | Accuracy =>  0.2738
# Epoch  7, CIFAR-10 Batch 1:  Loss =>  2.02136  | Accuracy =>  0.2772
# Epoch  7, CIFAR-10 Batch 2:  Loss =>  1.91955  | Accuracy =>  0.2816
# Epoch  7, CIFAR-10 Batch 3:  Loss =>  1.90308  | Accuracy =>  0.2826
# Epoch  7, CIFAR-10 Batch 4:  Loss =>  1.89882  | Accuracy =>  0.2812
# Epoch  7, CIFAR-10 Batch 5:  Loss =>  1.93761  | Accuracy =>  0.2814
# Epoch  8, CIFAR-10 Batch 1:  Loss =>  2.00397  | Accuracy =>  0.287
# Epoch  8, CIFAR-10 Batch 2:  Loss =>  1.90158  | Accuracy =>  0.2884
# Epoch  8, CIFAR-10 Batch 3:  Loss =>  1.87322  | Accuracy =>  0.2916
# Epoch  8, CIFAR-10 Batch 4:  Loss =>  1.87594  | Accuracy =>  0.286
# Epoch  8, CIFAR-10 Batch 5:  Loss =>  1.91427  | Accuracy =>  0.2886
# Epoch  9, CIFAR-10 Batch 1:  Loss =>  1.97811  | Accuracy =>  0.2906
# Epoch  9, CIFAR-10 Batch 2:  Loss =>  1.87805  | Accuracy =>  0.2916
# Epoch  9, CIFAR-10 Batch 3:  Loss =>  1.85123  | Accuracy =>  0.2916
# Epoch  9, CIFAR-10 Batch 4:  Loss =>  1.84747  | Accuracy =>  0.2956
# Epoch  9, CIFAR-10 Batch 5:  Loss =>  1.89443  | Accuracy =>  0.2904
# Epoch 10, CIFAR-10 Batch 1:  Loss =>  1.95532  | Accuracy =>  0.3
# Epoch 10, CIFAR-10 Batch 2:  Loss =>  1.85795  | Accuracy =>  0.3032
# Epoch 10, CIFAR-10 Batch 3:  Loss =>  1.83116  | Accuracy =>  0.304
# Epoch 10, CIFAR-10 Batch 4:  Loss =>  1.83192  | Accuracy =>  0.3004
# Epoch 10, CIFAR-10 Batch 5:  Loss =>  1.869  | Accuracy =>  0.3
# Epoch 11, CIFAR-10 Batch 1:  Loss =>  1.93487  | Accuracy =>  0.3026
# Epoch 11, CIFAR-10 Batch 2:  Loss =>  1.84  | Accuracy =>  0.3044
# Epoch 11, CIFAR-10 Batch 3:  Loss =>  1.81042  | Accuracy =>  0.302
# Epoch 11, CIFAR-10 Batch 4:  Loss =>  1.81002  | Accuracy =>  0.3042
# Epoch 11, CIFAR-10 Batch 5:  Loss =>  1.85613  | Accuracy =>  0.3046
# Epoch 12, CIFAR-10 Batch 1:  Loss =>  1.92334  | Accuracy =>  0.3064
# Epoch 12, CIFAR-10 Batch 2:  Loss =>  1.8248  | Accuracy =>  0.3056
# Epoch 12, CIFAR-10 Batch 3:  Loss =>  1.7974  | Accuracy =>  0.3096
# Epoch 12, CIFAR-10 Batch 4:  Loss =>  1.79956  | Accuracy =>  0.3144
# Epoch 12, CIFAR-10 Batch 5:  Loss =>  1.8425  | Accuracy =>  0.3062
# Epoch 13, CIFAR-10 Batch 1:  Loss =>  1.89767  | Accuracy =>  0.313
# Epoch 13, CIFAR-10 Batch 2:  Loss =>  1.8105  | Accuracy =>  0.316
# Epoch 13, CIFAR-10 Batch 3:  Loss =>  1.78037  | Accuracy =>  0.3146
# Epoch 13, CIFAR-10 Batch 4:  Loss =>  1.78403  | Accuracy =>  0.3178
# Epoch 13, CIFAR-10 Batch 5:  Loss =>  1.82724  | Accuracy =>  0.3158
# Epoch 14, CIFAR-10 Batch 1:  Loss =>  1.8857  | Accuracy =>  0.3156
# Epoch 14, CIFAR-10 Batch 2:  Loss =>  1.79502  | Accuracy =>  0.323
# Epoch 14, CIFAR-10 Batch 3:  Loss =>  1.76731  | Accuracy =>  0.3218
# Epoch 14, CIFAR-10 Batch 4:  Loss =>  1.7673  | Accuracy =>  0.3228
# Epoch 14, CIFAR-10 Batch 5:  Loss =>  1.82289  | Accuracy =>  0.3262
# Epoch 15, CIFAR-10 Batch 1:  Loss =>  1.87012  | Accuracy =>  0.3222
# Epoch 15, CIFAR-10 Batch 2:  Loss =>  1.7803  | Accuracy =>  0.3282
# Epoch 15, CIFAR-10 Batch 3:  Loss =>  1.75532  | Accuracy =>  0.3258
# Epoch 15, CIFAR-10 Batch 4:  Loss =>  1.75796  | Accuracy =>  0.3338
# Epoch 15, CIFAR-10 Batch 5:  Loss =>  1.81188  | Accuracy =>  0.3256
# Epoch 16, CIFAR-10 Batch 1:  Loss =>  1.85022  | Accuracy =>  0.3304
# Epoch 16, CIFAR-10 Batch 2:  Loss =>  1.76823  | Accuracy =>  0.3338
# Epoch 16, CIFAR-10 Batch 3:  Loss =>  1.73605  | Accuracy =>  0.3354
# Epoch 16, CIFAR-10 Batch 4:  Loss =>  1.74621  | Accuracy =>  0.3386
# Epoch 16, CIFAR-10 Batch 5:  Loss =>  1.80058  | Accuracy =>  0.334
# Epoch 17, CIFAR-10 Batch 1:  Loss =>  1.85211  | Accuracy =>  0.336
# Epoch 17, CIFAR-10 Batch 2:  Loss =>  1.75978  | Accuracy =>  0.339
# Epoch 17, CIFAR-10 Batch 3:  Loss =>  1.72725  | Accuracy =>  0.3398
# Epoch 17, CIFAR-10 Batch 4:  Loss =>  1.74066  | Accuracy =>  0.3428
# Epoch 17, CIFAR-10 Batch 5:  Loss =>  1.79937  | Accuracy =>  0.3382
# Epoch 18, CIFAR-10 Batch 1:  Loss =>  1.82922  | Accuracy =>  0.3376
# Epoch 18, CIFAR-10 Batch 2:  Loss =>  1.75164  | Accuracy =>  0.3466
# Epoch 18, CIFAR-10 Batch 3:  Loss =>  1.71739  | Accuracy =>  0.3488
# Epoch 18, CIFAR-10 Batch 4:  Loss =>  1.72763  | Accuracy =>  0.3494
# Epoch 18, CIFAR-10 Batch 5:  Loss =>  1.78531  | Accuracy =>  0.3462
# Epoch 19, CIFAR-10 Batch 1:  Loss =>  1.83816  | Accuracy =>  0.3418
# Epoch 19, CIFAR-10 Batch 2:  Loss =>  1.73516  | Accuracy =>  0.3484
# Epoch 19, CIFAR-10 Batch 3:  Loss =>  1.70407  | Accuracy =>  0.3462
# Epoch 19, CIFAR-10 Batch 4:  Loss =>  1.71988  | Accuracy =>  0.3564
# Epoch 19, CIFAR-10 Batch 5:  Loss =>  1.77956  | Accuracy =>  0.3516
# Epoch 20, CIFAR-10 Batch 1:  Loss =>  1.82409  | Accuracy =>  0.3508
# Epoch 20, CIFAR-10 Batch 2:  Loss =>  1.72781  | Accuracy =>  0.3524
# Epoch 20, CIFAR-10 Batch 3:  Loss =>  1.69363  | Accuracy =>  0.3456
# Epoch 20, CIFAR-10 Batch 4:  Loss =>  1.70956  | Accuracy =>  0.3562
# Epoch 20, CIFAR-10 Batch 5:  Loss =>  1.76847  | Accuracy =>  0.3522
# Epoch 21, CIFAR-10 Batch 1:  Loss =>  1.82529  | Accuracy =>  0.3516
# Epoch 21, CIFAR-10 Batch 2:  Loss =>  1.71465  | Accuracy =>  0.3582
# Epoch 21, CIFAR-10 Batch 3:  Loss =>  1.69422  | Accuracy =>  0.3534
# Epoch 21, CIFAR-10 Batch 4:  Loss =>  1.69897  | Accuracy =>  0.3592
# Epoch 21, CIFAR-10 Batch 5:  Loss =>  1.76665  | Accuracy =>  0.3552
# Epoch 22, CIFAR-10 Batch 1:  Loss =>  1.80816  | Accuracy =>  0.3604
# Epoch 22, CIFAR-10 Batch 2:  Loss =>  1.71013  | Accuracy =>  0.3642
# Epoch 22, CIFAR-10 Batch 3:  Loss =>  1.67852  | Accuracy =>  0.3532
# Epoch 22, CIFAR-10 Batch 4:  Loss =>  1.69693  | Accuracy =>  0.3626
# Epoch 22, CIFAR-10 Batch 5:  Loss =>  1.76372  | Accuracy =>  0.3596
# Epoch 23, CIFAR-10 Batch 1:  Loss =>  1.80169  | Accuracy =>  0.3592
# Epoch 23, CIFAR-10 Batch 2:  Loss =>  1.70189  | Accuracy =>  0.3686
# Epoch 23, CIFAR-10 Batch 3:  Loss =>  1.66777  | Accuracy =>  0.3596
# Epoch 23, CIFAR-10 Batch 4:  Loss =>  1.6863  | Accuracy =>  0.365
# Epoch 23, CIFAR-10 Batch 5:  Loss =>  1.75705  | Accuracy =>  0.362
# Epoch 24, CIFAR-10 Batch 1:  Loss =>  1.80466  | Accuracy =>  0.3626
# Epoch 24, CIFAR-10 Batch 2:  Loss =>  1.6916  | Accuracy =>  0.3686
# Epoch 24, CIFAR-10 Batch 3:  Loss =>  1.66294  | Accuracy =>  0.3616
# Epoch 24, CIFAR-10 Batch 4:  Loss =>  1.68539  | Accuracy =>  0.3674
# Epoch 24, CIFAR-10 Batch 5:  Loss =>  1.74585  | Accuracy =>  0.3646
# Epoch 25, CIFAR-10 Batch 1:  Loss =>  1.7962  | Accuracy =>  0.3676
# Epoch 25, CIFAR-10 Batch 2:  Loss =>  1.68497  | Accuracy =>  0.3714
# Epoch 25, CIFAR-10 Batch 3:  Loss =>  1.65784  | Accuracy =>  0.3672
# Epoch 25, CIFAR-10 Batch 4:  Loss =>  1.67468  | Accuracy =>  0.37
# Epoch 25, CIFAR-10 Batch 5:  Loss =>  1.74415  | Accuracy =>  0.367
# Epoch 26, CIFAR-10 Batch 1:  Loss =>  1.80029  | Accuracy =>  0.368
# Epoch 26, CIFAR-10 Batch 2:  Loss =>  1.67633  | Accuracy =>  0.3742
# Epoch 26, CIFAR-10 Batch 3:  Loss =>  1.6516  | Accuracy =>  0.3696
# Epoch 26, CIFAR-10 Batch 4:  Loss =>  1.67177  | Accuracy =>  0.369
# Epoch 26, CIFAR-10 Batch 5:  Loss =>  1.73823  | Accuracy =>  0.3688
# Epoch 27, CIFAR-10 Batch 1:  Loss =>  1.78844  | Accuracy =>  0.3656
# Epoch 27, CIFAR-10 Batch 2:  Loss =>  1.6738  | Accuracy =>  0.3764
# Epoch 27, CIFAR-10 Batch 3:  Loss =>  1.63838  | Accuracy =>  0.372
# Epoch 27, CIFAR-10 Batch 4:  Loss =>  1.67049  | Accuracy =>  0.3734
# Epoch 27, CIFAR-10 Batch 5:  Loss =>  1.73604  | Accuracy =>  0.3682
# Epoch 28, CIFAR-10 Batch 1:  Loss =>  1.78561  | Accuracy =>  0.3748
# Epoch 28, CIFAR-10 Batch 2:  Loss =>  1.65621  | Accuracy =>  0.3758
# Epoch 28, CIFAR-10 Batch 3:  Loss =>  1.63234  | Accuracy =>  0.3738
# Epoch 28, CIFAR-10 Batch 4:  Loss =>  1.66509  | Accuracy =>  0.3726
# Epoch 28, CIFAR-10 Batch 5:  Loss =>  1.728  | Accuracy =>  0.3704
# Epoch 29, CIFAR-10 Batch 1:  Loss =>  1.78585  | Accuracy =>  0.371
# Epoch 29, CIFAR-10 Batch 2:  Loss =>  1.65018  | Accuracy =>  0.3788
# Epoch 29, CIFAR-10 Batch 3:  Loss =>  1.63056  | Accuracy =>  0.3722
# Epoch 29, CIFAR-10 Batch 4:  Loss =>  1.65527  | Accuracy =>  0.3748
# Epoch 29, CIFAR-10 Batch 5:  Loss =>  1.72717  | Accuracy =>  0.3708
# Epoch 30, CIFAR-10 Batch 1:  Loss =>  1.76988  | Accuracy =>  0.375
# Epoch 30, CIFAR-10 Batch 2:  Loss =>  1.64154  | Accuracy =>  0.3798
# Epoch 30, CIFAR-10 Batch 3:  Loss =>  1.62278  | Accuracy =>  0.3766
# Epoch 30, CIFAR-10 Batch 4:  Loss =>  1.64584  | Accuracy =>  0.3764
# Epoch 30, CIFAR-10 Batch 5:  Loss =>  1.72087  | Accuracy =>  0.3738
# Epoch 31, CIFAR-10 Batch 1:  Loss =>  1.77641  | Accuracy =>  0.3786
# Epoch 31, CIFAR-10 Batch 2:  Loss =>  1.64394  | Accuracy =>  0.3822
# Epoch 31, CIFAR-10 Batch 3:  Loss =>  1.60935  | Accuracy =>  0.3774
# Epoch 31, CIFAR-10 Batch 4:  Loss =>  1.64397  | Accuracy =>  0.378
# Epoch 31, CIFAR-10 Batch 5:  Loss =>  1.72712  | Accuracy =>  0.3764
# Epoch 32, CIFAR-10 Batch 1:  Loss =>  1.76199  | Accuracy =>  0.3796
# Epoch 32, CIFAR-10 Batch 2:  Loss =>  1.63099  | Accuracy =>  0.38
# Epoch 32, CIFAR-10 Batch 3:  Loss =>  1.60773  | Accuracy =>  0.3806
# Epoch 32, CIFAR-10 Batch 4:  Loss =>  1.63942  | Accuracy =>  0.3794
# Epoch 32, CIFAR-10 Batch 5:  Loss =>  1.71061  | Accuracy =>  0.3768
# Epoch 33, CIFAR-10 Batch 1:  Loss =>  1.76099  | Accuracy =>  0.3814
# Epoch 33, CIFAR-10 Batch 2:  Loss =>  1.62711  | Accuracy =>  0.382
# Epoch 33, CIFAR-10 Batch 3:  Loss =>  1.60743  | Accuracy =>  0.3858
# Epoch 33, CIFAR-10 Batch 4:  Loss =>  1.63694  | Accuracy =>  0.381
# Epoch 33, CIFAR-10 Batch 5:  Loss =>  1.71336  | Accuracy =>  0.3806
# Epoch 34, CIFAR-10 Batch 1:  Loss =>  1.7682  | Accuracy =>  0.3846
# Epoch 34, CIFAR-10 Batch 2:  Loss =>  1.61453  | Accuracy =>  0.3838
# Epoch 34, CIFAR-10 Batch 3:  Loss =>  1.60418  | Accuracy =>  0.386
# Epoch 34, CIFAR-10 Batch 4:  Loss =>  1.62569  | Accuracy =>  0.3814
# Epoch 34, CIFAR-10 Batch 5:  Loss =>  1.71048  | Accuracy =>  0.3808
# Epoch 35, CIFAR-10 Batch 1:  Loss =>  1.74984  | Accuracy =>  0.3814
# Epoch 35, CIFAR-10 Batch 2:  Loss =>  1.6147  | Accuracy =>  0.3856
# Epoch 35, CIFAR-10 Batch 3:  Loss =>  1.60334  | Accuracy =>  0.3828
# Epoch 35, CIFAR-10 Batch 4:  Loss =>  1.62453  | Accuracy =>  0.3826
# Epoch 35, CIFAR-10 Batch 5:  Loss =>  1.70268  | Accuracy =>  0.3798
# Epoch 36, CIFAR-10 Batch 1:  Loss =>  1.74242  | Accuracy =>  0.386
# Epoch 36, CIFAR-10 Batch 2:  Loss =>  1.61173  | Accuracy =>  0.383
# Epoch 36, CIFAR-10 Batch 3:  Loss =>  1.59579  | Accuracy =>  0.3884
# Epoch 36, CIFAR-10 Batch 4:  Loss =>  1.61974  | Accuracy =>  0.3816
# Epoch 36, CIFAR-10 Batch 5:  Loss =>  1.70576  | Accuracy =>  0.3808
# Epoch 37, CIFAR-10 Batch 1:  Loss =>  1.75636  | Accuracy =>  0.3818
# Epoch 37, CIFAR-10 Batch 2:  Loss =>  1.60956  | Accuracy =>  0.3834
# Epoch 37, CIFAR-10 Batch 3:  Loss =>  1.60038  | Accuracy =>  0.3866
# Epoch 37, CIFAR-10 Batch 4:  Loss =>  1.61864  | Accuracy =>  0.3838
# Epoch 37, CIFAR-10 Batch 5:  Loss =>  1.69404  | Accuracy =>  0.382
# Epoch 38, CIFAR-10 Batch 1:  Loss =>  1.75089  | Accuracy =>  0.3856
# Epoch 38, CIFAR-10 Batch 2:  Loss =>  1.60222  | Accuracy =>  0.387
# Epoch 38, CIFAR-10 Batch 3:  Loss =>  1.60325  | Accuracy =>  0.3894
# Epoch 38, CIFAR-10 Batch 4:  Loss =>  1.61225  | Accuracy =>  0.3886
# Epoch 38, CIFAR-10 Batch 5:  Loss =>  1.70105  | Accuracy =>  0.382
# Epoch 39, CIFAR-10 Batch 1:  Loss =>  1.73572  | Accuracy =>  0.3838
# Epoch 39, CIFAR-10 Batch 2:  Loss =>  1.6049  | Accuracy =>  0.384
# Epoch 39, CIFAR-10 Batch 3:  Loss =>  1.59196  | Accuracy =>  0.3908
# Epoch 39, CIFAR-10 Batch 4:  Loss =>  1.60939  | Accuracy =>  0.387
# Epoch 39, CIFAR-10 Batch 5:  Loss =>  1.69185  | Accuracy =>  0.3846
# Epoch 40, CIFAR-10 Batch 1:  Loss =>  1.73918  | Accuracy =>  0.3868
# Epoch 40, CIFAR-10 Batch 2:  Loss =>  1.60191  | Accuracy =>  0.39
# Epoch 40, CIFAR-10 Batch 3:  Loss =>  1.58319  | Accuracy =>  0.3892
# Epoch 40, CIFAR-10 Batch 4:  Loss =>  1.60409  | Accuracy =>  0.3858
# Epoch 40, CIFAR-10 Batch 5:  Loss =>  1.69079  | Accuracy =>  0.3848
# Epoch 41, CIFAR-10 Batch 1:  Loss =>  1.74671  | Accuracy =>  0.3898
# Epoch 41, CIFAR-10 Batch 2:  Loss =>  1.59008  | Accuracy =>  0.3894
# Epoch 41, CIFAR-10 Batch 3:  Loss =>  1.58512  | Accuracy =>  0.3872
# Epoch 41, CIFAR-10 Batch 4:  Loss =>  1.60225  | Accuracy =>  0.387
# Epoch 41, CIFAR-10 Batch 5:  Loss =>  1.68793  | Accuracy =>  0.3856
# Epoch 42, CIFAR-10 Batch 1:  Loss =>  1.73153  | Accuracy =>  0.389
# Epoch 42, CIFAR-10 Batch 2:  Loss =>  1.58954  | Accuracy =>  0.3908
# Epoch 42, CIFAR-10 Batch 3:  Loss =>  1.57637  | Accuracy =>  0.3938
# Epoch 42, CIFAR-10 Batch 4:  Loss =>  1.60403  | Accuracy =>  0.3856
# Epoch 42, CIFAR-10 Batch 5:  Loss =>  1.68488  | Accuracy =>  0.382
# Epoch 43, CIFAR-10 Batch 1:  Loss =>  1.73359  | Accuracy =>  0.3912
# Epoch 43, CIFAR-10 Batch 2:  Loss =>  1.58511  | Accuracy =>  0.3902
# Epoch 43, CIFAR-10 Batch 3:  Loss =>  1.56972  | Accuracy =>  0.3906
# Epoch 43, CIFAR-10 Batch 4:  Loss =>  1.59156  | Accuracy =>  0.3858
# Epoch 43, CIFAR-10 Batch 5:  Loss =>  1.68462  | Accuracy =>  0.3874
# Epoch 44, CIFAR-10 Batch 1:  Loss =>  1.73084  | Accuracy =>  0.3914
# Epoch 44, CIFAR-10 Batch 2:  Loss =>  1.58349  | Accuracy =>  0.3934
# Epoch 44, CIFAR-10 Batch 3:  Loss =>  1.56875  | Accuracy =>  0.3916
# Epoch 44, CIFAR-10 Batch 4:  Loss =>  1.58965  | Accuracy =>  0.3876
# Epoch 44, CIFAR-10 Batch 5:  Loss =>  1.68202  | Accuracy =>  0.3888
# Epoch 45, CIFAR-10 Batch 1:  Loss =>  1.71481  | Accuracy =>  0.3916
# Epoch 45, CIFAR-10 Batch 2:  Loss =>  1.58296  | Accuracy =>  0.393
# Epoch 45, CIFAR-10 Batch 3:  Loss =>  1.57248  | Accuracy =>  0.3946
# Epoch 45, CIFAR-10 Batch 4:  Loss =>  1.58773  | Accuracy =>  0.3898
# Epoch 45, CIFAR-10 Batch 5:  Loss =>  1.68049  | Accuracy =>  0.39
# Epoch 46, CIFAR-10 Batch 1:  Loss =>  1.73012  | Accuracy =>  0.3914
# Epoch 46, CIFAR-10 Batch 2:  Loss =>  1.58029  | Accuracy =>  0.3968
# Epoch 46, CIFAR-10 Batch 3:  Loss =>  1.57021  | Accuracy =>  0.3926
# Epoch 46, CIFAR-10 Batch 4:  Loss =>  1.5776  | Accuracy =>  0.3888
# Epoch 46, CIFAR-10 Batch 5:  Loss =>  1.68154  | Accuracy =>  0.3912
# Epoch 47, CIFAR-10 Batch 1:  Loss =>  1.71298  | Accuracy =>  0.3926
# Epoch 47, CIFAR-10 Batch 2:  Loss =>  1.57917  | Accuracy =>  0.3966
# Epoch 47, CIFAR-10 Batch 3:  Loss =>  1.56556  | Accuracy =>  0.3936
# Epoch 47, CIFAR-10 Batch 4:  Loss =>  1.57457  | Accuracy =>  0.3904
# Epoch 47, CIFAR-10 Batch 5:  Loss =>  1.67703  | Accuracy =>  0.3932
# Epoch 48, CIFAR-10 Batch 1:  Loss =>  1.71552  | Accuracy =>  0.3938
# Epoch 48, CIFAR-10 Batch 2:  Loss =>  1.57465  | Accuracy =>  0.3904
# Epoch 48, CIFAR-10 Batch 3:  Loss =>  1.56218  | Accuracy =>  0.3954
# Epoch 48, CIFAR-10 Batch 4:  Loss =>  1.57778  | Accuracy =>  0.393
# Epoch 48, CIFAR-10 Batch 5:  Loss =>  1.67048  | Accuracy =>  0.3934
# Epoch 49, CIFAR-10 Batch 1:  Loss =>  1.70128  | Accuracy =>  0.3952
# Epoch 49, CIFAR-10 Batch 2:  Loss =>  1.56672  | Accuracy =>  0.398
# Epoch 49, CIFAR-10 Batch 3:  Loss =>  1.557  | Accuracy =>  0.3964
# Epoch 49, CIFAR-10 Batch 4:  Loss =>  1.56847  | Accuracy =>  0.3902
# Epoch 49, CIFAR-10 Batch 5:  Loss =>  1.66748  | Accuracy =>  0.393
# Epoch 50, CIFAR-10 Batch 1:  Loss =>  1.70569  | Accuracy =>  0.3966
# Epoch 50, CIFAR-10 Batch 2:  Loss =>  1.56675  | Accuracy =>  0.396
# Epoch 50, CIFAR-10 Batch 3:  Loss =>  1.56352  | Accuracy =>  0.4012
# Epoch 50, CIFAR-10 Batch 4:  Loss =>  1.57246  | Accuracy =>  0.3928
# Epoch 50, CIFAR-10 Batch 5:  Loss =>  1.66794  | Accuracy =>  0.3904
# Epoch 51, CIFAR-10 Batch 1:  Loss =>  1.69742  | Accuracy =>  0.3974
# Epoch 51, CIFAR-10 Batch 2:  Loss =>  1.56267  | Accuracy =>  0.401
# Epoch 51, CIFAR-10 Batch 3:  Loss =>  1.55665  | Accuracy =>  0.3994
# Epoch 51, CIFAR-10 Batch 4:  Loss =>  1.56906  | Accuracy =>  0.3924
# Epoch 51, CIFAR-10 Batch 5:  Loss =>  1.6613  | Accuracy =>  0.3944
# Epoch 52, CIFAR-10 Batch 1:  Loss =>  1.70357  | Accuracy =>  0.4016
# Epoch 52, CIFAR-10 Batch 2:  Loss =>  1.56687  | Accuracy =>  0.4056
# Epoch 52, CIFAR-10 Batch 3:  Loss =>  1.55367  | Accuracy =>  0.402
# Epoch 52, CIFAR-10 Batch 4:  Loss =>  1.56572  | Accuracy =>  0.3924
# Epoch 52, CIFAR-10 Batch 5:  Loss =>  1.66176  | Accuracy =>  0.3944
# Epoch 53, CIFAR-10 Batch 1:  Loss =>  1.69239  | Accuracy =>  0.3986
# Epoch 53, CIFAR-10 Batch 2:  Loss =>  1.5521  | Accuracy =>  0.4036
# Epoch 53, CIFAR-10 Batch 3:  Loss =>  1.55859  | Accuracy =>  0.404
# Epoch 53, CIFAR-10 Batch 4:  Loss =>  1.56448  | Accuracy =>  0.3934
# Epoch 53, CIFAR-10 Batch 5:  Loss =>  1.65914  | Accuracy =>  0.3952
# Epoch 54, CIFAR-10 Batch 1:  Loss =>  1.69801  | Accuracy =>  0.4004
# Epoch 54, CIFAR-10 Batch 2:  Loss =>  1.55625  | Accuracy =>  0.401
# Epoch 54, CIFAR-10 Batch 3:  Loss =>  1.54756  | Accuracy =>  0.4002
# Epoch 54, CIFAR-10 Batch 4:  Loss =>  1.55468  | Accuracy =>  0.3998
# Epoch 54, CIFAR-10 Batch 5:  Loss =>  1.65382  | Accuracy =>  0.395
# Epoch 55, CIFAR-10 Batch 1:  Loss =>  1.68537  | Accuracy =>  0.405
# Epoch 55, CIFAR-10 Batch 2:  Loss =>  1.55335  | Accuracy =>  0.4028
# Epoch 55, CIFAR-10 Batch 3:  Loss =>  1.54621  | Accuracy =>  0.4024
# Epoch 55, CIFAR-10 Batch 4:  Loss =>  1.55548  | Accuracy =>  0.4014
# Epoch 55, CIFAR-10 Batch 5:  Loss =>  1.65668  | Accuracy =>  0.3964
# Epoch 56, CIFAR-10 Batch 1:  Loss =>  1.68367  | Accuracy =>  0.4038
# Epoch 56, CIFAR-10 Batch 2:  Loss =>  1.54072  | Accuracy =>  0.402
# Epoch 56, CIFAR-10 Batch 3:  Loss =>  1.55554  | Accuracy =>  0.406
# Epoch 56, CIFAR-10 Batch 4:  Loss =>  1.554  | Accuracy =>  0.3984
# Epoch 56, CIFAR-10 Batch 5:  Loss =>  1.65052  | Accuracy =>  0.3974
# Epoch 57, CIFAR-10 Batch 1:  Loss =>  1.68587  | Accuracy =>  0.4026
# Epoch 57, CIFAR-10 Batch 2:  Loss =>  1.5516  | Accuracy =>  0.405
# Epoch 57, CIFAR-10 Batch 3:  Loss =>  1.54107  | Accuracy =>  0.4054
# Epoch 57, CIFAR-10 Batch 4:  Loss =>  1.54818  | Accuracy =>  0.4008
# Epoch 57, CIFAR-10 Batch 5:  Loss =>  1.65686  | Accuracy =>  0.397
# Epoch 58, CIFAR-10 Batch 1:  Loss =>  1.67801  | Accuracy =>  0.403
# Epoch 58, CIFAR-10 Batch 2:  Loss =>  1.55104  | Accuracy =>  0.4014
# Epoch 58, CIFAR-10 Batch 3:  Loss =>  1.53785  | Accuracy =>  0.4038
# Epoch 58, CIFAR-10 Batch 4:  Loss =>  1.53891  | Accuracy =>  0.4028
# Epoch 58, CIFAR-10 Batch 5:  Loss =>  1.65094  | Accuracy =>  0.3998
# Epoch 59, CIFAR-10 Batch 1:  Loss =>  1.67758  | Accuracy =>  0.408
# Epoch 59, CIFAR-10 Batch 2:  Loss =>  1.55394  | Accuracy =>  0.407
# Epoch 59, CIFAR-10 Batch 3:  Loss =>  1.53378  | Accuracy =>  0.4074
# Epoch 59, CIFAR-10 Batch 4:  Loss =>  1.54642  | Accuracy =>  0.4016
# Epoch 59, CIFAR-10 Batch 5:  Loss =>  1.64793  | Accuracy =>  0.4038
# Epoch 60, CIFAR-10 Batch 1:  Loss =>  1.66992  | Accuracy =>  0.4084
# Epoch 60, CIFAR-10 Batch 2:  Loss =>  1.54649  | Accuracy =>  0.4072
# Epoch 60, CIFAR-10 Batch 3:  Loss =>  1.53326  | Accuracy =>  0.4036
# Epoch 60, CIFAR-10 Batch 4:  Loss =>  1.54526  | Accuracy =>  0.407
# Epoch 60, CIFAR-10 Batch 5:  Loss =>  1.64983  | Accuracy =>  0.3992
# Epoch 61, CIFAR-10 Batch 1:  Loss =>  1.67804  | Accuracy =>  0.4092
# Epoch 61, CIFAR-10 Batch 2:  Loss =>  1.54498  | Accuracy =>  0.407
# Epoch 61, CIFAR-10 Batch 3:  Loss =>  1.53525  | Accuracy =>  0.4068
# Epoch 61, CIFAR-10 Batch 4:  Loss =>  1.54543  | Accuracy =>  0.4032
# Epoch 61, CIFAR-10 Batch 5:  Loss =>  1.64458  | Accuracy =>  0.4042
# Epoch 62, CIFAR-10 Batch 1:  Loss =>  1.67455  | Accuracy =>  0.4118
# Epoch 62, CIFAR-10 Batch 2:  Loss =>  1.53066  | Accuracy =>  0.4082
# Epoch 62, CIFAR-10 Batch 3:  Loss =>  1.53661  | Accuracy =>  0.4078
# Epoch 62, CIFAR-10 Batch 4:  Loss =>  1.5345  | Accuracy =>  0.407
# Epoch 62, CIFAR-10 Batch 5:  Loss =>  1.64758  | Accuracy =>  0.4034
# Epoch 63, CIFAR-10 Batch 1:  Loss =>  1.67438  | Accuracy =>  0.4108
# Epoch 63, CIFAR-10 Batch 2:  Loss =>  1.53248  | Accuracy =>  0.4124
# Epoch 63, CIFAR-10 Batch 3:  Loss =>  1.52808  | Accuracy =>  0.407
# Epoch 63, CIFAR-10 Batch 4:  Loss =>  1.53233  | Accuracy =>  0.4068
# Epoch 63, CIFAR-10 Batch 5:  Loss =>  1.63855  | Accuracy =>  0.4018
# Epoch 64, CIFAR-10 Batch 1:  Loss =>  1.67013  | Accuracy =>  0.4108
# Epoch 64, CIFAR-10 Batch 2:  Loss =>  1.54069  | Accuracy =>  0.4106
# Epoch 64, CIFAR-10 Batch 3:  Loss =>  1.52542  | Accuracy =>  0.406
# Epoch 64, CIFAR-10 Batch 4:  Loss =>  1.5331  | Accuracy =>  0.404
# Epoch 64, CIFAR-10 Batch 5:  Loss =>  1.64169  | Accuracy =>  0.405
# Epoch 65, CIFAR-10 Batch 1:  Loss =>  1.67008  | Accuracy =>  0.4112
# Epoch 65, CIFAR-10 Batch 2:  Loss =>  1.53922  | Accuracy =>  0.4092
# Epoch 65, CIFAR-10 Batch 3:  Loss =>  1.52718  | Accuracy =>  0.4112
# Epoch 65, CIFAR-10 Batch 4:  Loss =>  1.52497  | Accuracy =>  0.4078
# Epoch 65, CIFAR-10 Batch 5:  Loss =>  1.645  | Accuracy =>  0.4048
# Epoch 66, CIFAR-10 Batch 1:  Loss =>  1.6749  | Accuracy =>  0.4098
# Epoch 66, CIFAR-10 Batch 2:  Loss =>  1.53108  | Accuracy =>  0.41
# Epoch 66, CIFAR-10 Batch 3:  Loss =>  1.52755  | Accuracy =>  0.4116
# Epoch 66, CIFAR-10 Batch 4:  Loss =>  1.5225  | Accuracy =>  0.41
# Epoch 66, CIFAR-10 Batch 5:  Loss =>  1.64312  | Accuracy =>  0.4064
# Epoch 67, CIFAR-10 Batch 1:  Loss =>  1.67318  | Accuracy =>  0.413
# Epoch 67, CIFAR-10 Batch 2:  Loss =>  1.53183  | Accuracy =>  0.4146
# Epoch 67, CIFAR-10 Batch 3:  Loss =>  1.52352  | Accuracy =>  0.4098
# Epoch 67, CIFAR-10 Batch 4:  Loss =>  1.52213  | Accuracy =>  0.4052
# Epoch 67, CIFAR-10 Batch 5:  Loss =>  1.63794  | Accuracy =>  0.4022
# Epoch 68, CIFAR-10 Batch 1:  Loss =>  1.66766  | Accuracy =>  0.4132
# Epoch 68, CIFAR-10 Batch 2:  Loss =>  1.53359  | Accuracy =>  0.413
# Epoch 68, CIFAR-10 Batch 3:  Loss =>  1.51654  | Accuracy =>  0.406
# Epoch 68, CIFAR-10 Batch 4:  Loss =>  1.51757  | Accuracy =>  0.4094
# Epoch 68, CIFAR-10 Batch 5:  Loss =>  1.63802  | Accuracy =>  0.4062
# Epoch 69, CIFAR-10 Batch 1:  Loss =>  1.66704  | Accuracy =>  0.4116
# Epoch 69, CIFAR-10 Batch 2:  Loss =>  1.53016  | Accuracy =>  0.4122
# Epoch 69, CIFAR-10 Batch 3:  Loss =>  1.52642  | Accuracy =>  0.4118
# Epoch 69, CIFAR-10 Batch 4:  Loss =>  1.51951  | Accuracy =>  0.4116
# Epoch 69, CIFAR-10 Batch 5:  Loss =>  1.63448  | Accuracy =>  0.4052
# Epoch 70, CIFAR-10 Batch 1:  Loss =>  1.66968  | Accuracy =>  0.4148
# Epoch 70, CIFAR-10 Batch 2:  Loss =>  1.52005  | Accuracy =>  0.4148
# Epoch 70, CIFAR-10 Batch 3:  Loss =>  1.51358  | Accuracy =>  0.411
# Epoch 70, CIFAR-10 Batch 4:  Loss =>  1.5165  | Accuracy =>  0.414
# Epoch 70, CIFAR-10 Batch 5:  Loss =>  1.63555  | Accuracy =>  0.4056
# Epoch 71, CIFAR-10 Batch 1:  Loss =>  1.65871  | Accuracy =>  0.4128
# Epoch 71, CIFAR-10 Batch 2:  Loss =>  1.52811  | Accuracy =>  0.4118
# Epoch 71, CIFAR-10 Batch 3:  Loss =>  1.517  | Accuracy =>  0.412
# Epoch 71, CIFAR-10 Batch 4:  Loss =>  1.51849  | Accuracy =>  0.4092
# Epoch 71, CIFAR-10 Batch 5:  Loss =>  1.63584  | Accuracy =>  0.4056
# Epoch 72, CIFAR-10 Batch 1:  Loss =>  1.66361  | Accuracy =>  0.4136
# Epoch 72, CIFAR-10 Batch 2:  Loss =>  1.52187  | Accuracy =>  0.4156
# Epoch 72, CIFAR-10 Batch 3:  Loss =>  1.50906  | Accuracy =>  0.4112
# Epoch 72, CIFAR-10 Batch 4:  Loss =>  1.51798  | Accuracy =>  0.409
# Epoch 72, CIFAR-10 Batch 5:  Loss =>  1.63434  | Accuracy =>  0.4056
# Epoch 73, CIFAR-10 Batch 1:  Loss =>  1.65838  | Accuracy =>  0.4138
# Epoch 73, CIFAR-10 Batch 2:  Loss =>  1.51783  | Accuracy =>  0.4152
# Epoch 73, CIFAR-10 Batch 3:  Loss =>  1.51028  | Accuracy =>  0.4114
# Epoch 73, CIFAR-10 Batch 4:  Loss =>  1.50784  | Accuracy =>  0.4152
# Epoch 73, CIFAR-10 Batch 5:  Loss =>  1.6363  | Accuracy =>  0.403
# Epoch 74, CIFAR-10 Batch 1:  Loss =>  1.64852  | Accuracy =>  0.4128
# Epoch 74, CIFAR-10 Batch 2:  Loss =>  1.52446  | Accuracy =>  0.4146
# Epoch 74, CIFAR-10 Batch 3:  Loss =>  1.50646  | Accuracy =>  0.4088
# Epoch 74, CIFAR-10 Batch 4:  Loss =>  1.50889  | Accuracy =>  0.4146
# Epoch 74, CIFAR-10 Batch 5:  Loss =>  1.633  | Accuracy =>  0.4102
# Epoch 75, CIFAR-10 Batch 1:  Loss =>  1.64788  | Accuracy =>  0.4126
# Epoch 75, CIFAR-10 Batch 2:  Loss =>  1.52178  | Accuracy =>  0.414
# Epoch 75, CIFAR-10 Batch 3:  Loss =>  1.50476  | Accuracy =>  0.412
# Epoch 75, CIFAR-10 Batch 4:  Loss =>  1.50418  | Accuracy =>  0.4174
# Epoch 75, CIFAR-10 Batch 5:  Loss =>  1.62914  | Accuracy =>  0.41
# Epoch 76, CIFAR-10 Batch 1:  Loss =>  1.65942  | Accuracy =>  0.4156
# Epoch 76, CIFAR-10 Batch 2:  Loss =>  1.52171  | Accuracy =>  0.4178
# Epoch 76, CIFAR-10 Batch 3:  Loss =>  1.49974  | Accuracy =>  0.4158
# Epoch 76, CIFAR-10 Batch 4:  Loss =>  1.50372  | Accuracy =>  0.4122
# Epoch 76, CIFAR-10 Batch 5:  Loss =>  1.63766  | Accuracy =>  0.4062
# Epoch 77, CIFAR-10 Batch 1:  Loss =>  1.66126  | Accuracy =>  0.4198
# Epoch 77, CIFAR-10 Batch 2:  Loss =>  1.51662  | Accuracy =>  0.417
# Epoch 77, CIFAR-10 Batch 3:  Loss =>  1.50488  | Accuracy =>  0.4112
# Epoch 77, CIFAR-10 Batch 4:  Loss =>  1.50083  | Accuracy =>  0.4162
# Epoch 77, CIFAR-10 Batch 5:  Loss =>  1.63374  | Accuracy =>  0.4098
# Epoch 78, CIFAR-10 Batch 1:  Loss =>  1.65715  | Accuracy =>  0.4148
# Epoch 78, CIFAR-10 Batch 2:  Loss =>  1.51373  | Accuracy =>  0.4176
# Epoch 78, CIFAR-10 Batch 3:  Loss =>  1.50111  | Accuracy =>  0.4146
# Epoch 78, CIFAR-10 Batch 4:  Loss =>  1.50351  | Accuracy =>  0.4078
# Epoch 78, CIFAR-10 Batch 5:  Loss =>  1.63542  | Accuracy =>  0.4144
# Epoch 79, CIFAR-10 Batch 1:  Loss =>  1.66164  | Accuracy =>  0.4122
# Epoch 79, CIFAR-10 Batch 2:  Loss =>  1.5163  | Accuracy =>  0.4186
# Epoch 79, CIFAR-10 Batch 3:  Loss =>  1.49845  | Accuracy =>  0.4122
# Epoch 79, CIFAR-10 Batch 4:  Loss =>  1.49466  | Accuracy =>  0.4164
# Epoch 79, CIFAR-10 Batch 5:  Loss =>  1.6218  | Accuracy =>  0.4118
# Epoch 80, CIFAR-10 Batch 1:  Loss =>  1.65322  | Accuracy =>  0.4156
# Epoch 80, CIFAR-10 Batch 2:  Loss =>  1.51338  | Accuracy =>  0.4172
# Epoch 80, CIFAR-10 Batch 3:  Loss =>  1.49759  | Accuracy =>  0.414
# Epoch 80, CIFAR-10 Batch 4:  Loss =>  1.49719  | Accuracy =>  0.412
# Epoch 80, CIFAR-10 Batch 5:  Loss =>  1.63128  | Accuracy =>  0.4072
# Epoch 81, CIFAR-10 Batch 1:  Loss =>  1.65311  | Accuracy =>  0.4118
# Epoch 81, CIFAR-10 Batch 2:  Loss =>  1.51334  | Accuracy =>  0.4174
# Epoch 81, CIFAR-10 Batch 3:  Loss =>  1.50212  | Accuracy =>  0.4158
# Epoch 81, CIFAR-10 Batch 4:  Loss =>  1.49267  | Accuracy =>  0.4136
# Epoch 81, CIFAR-10 Batch 5:  Loss =>  1.62597  | Accuracy =>  0.4148
# Epoch 82, CIFAR-10 Batch 1:  Loss =>  1.65654  | Accuracy =>  0.4148
# Epoch 82, CIFAR-10 Batch 2:  Loss =>  1.51021  | Accuracy =>  0.4166
# Epoch 82, CIFAR-10 Batch 3:  Loss =>  1.50311  | Accuracy =>  0.4164
# Epoch 82, CIFAR-10 Batch 4:  Loss =>  1.49084  | Accuracy =>  0.4152
# Epoch 82, CIFAR-10 Batch 5:  Loss =>  1.62506  | Accuracy =>  0.4054
# Epoch 83, CIFAR-10 Batch 1:  Loss =>  1.64687  | Accuracy =>  0.4176
# Epoch 83, CIFAR-10 Batch 2:  Loss =>  1.50149  | Accuracy =>  0.4182
# Epoch 83, CIFAR-10 Batch 3:  Loss =>  1.50502  | Accuracy =>  0.4148
# Epoch 83, CIFAR-10 Batch 4:  Loss =>  1.49113  | Accuracy =>  0.4174
# Epoch 83, CIFAR-10 Batch 5:  Loss =>  1.62874  | Accuracy =>  0.412
# Epoch 84, CIFAR-10 Batch 1:  Loss =>  1.64842  | Accuracy =>  0.4204
# Epoch 84, CIFAR-10 Batch 2:  Loss =>  1.50728  | Accuracy =>  0.4188
# Epoch 84, CIFAR-10 Batch 3:  Loss =>  1.49418  | Accuracy =>  0.4188
# Epoch 84, CIFAR-10 Batch 4:  Loss =>  1.487  | Accuracy =>  0.414
# Epoch 84, CIFAR-10 Batch 5:  Loss =>  1.62769  | Accuracy =>  0.409
# Epoch 85, CIFAR-10 Batch 1:  Loss =>  1.64505  | Accuracy =>  0.4148
# Epoch 85, CIFAR-10 Batch 2:  Loss =>  1.51043  | Accuracy =>  0.4174
# Epoch 85, CIFAR-10 Batch 3:  Loss =>  1.49156  | Accuracy =>  0.4224
# Epoch 85, CIFAR-10 Batch 4:  Loss =>  1.49397  | Accuracy =>  0.4124
# Epoch 85, CIFAR-10 Batch 5:  Loss =>  1.62292  | Accuracy =>  0.416
# Epoch 86, CIFAR-10 Batch 1:  Loss =>  1.64318  | Accuracy =>  0.4158
# Epoch 86, CIFAR-10 Batch 2:  Loss =>  1.505  | Accuracy =>  0.42
# Epoch 86, CIFAR-10 Batch 3:  Loss =>  1.50091  | Accuracy =>  0.4178
# Epoch 86, CIFAR-10 Batch 4:  Loss =>  1.48403  | Accuracy =>  0.4172
# Epoch 86, CIFAR-10 Batch 5:  Loss =>  1.62378  | Accuracy =>  0.4108
# Epoch 87, CIFAR-10 Batch 1:  Loss =>  1.64039  | Accuracy =>  0.4186
# Epoch 87, CIFAR-10 Batch 2:  Loss =>  1.50812  | Accuracy =>  0.4172
# Epoch 87, CIFAR-10 Batch 3:  Loss =>  1.49685  | Accuracy =>  0.4156
# Epoch 87, CIFAR-10 Batch 4:  Loss =>  1.48637  | Accuracy =>  0.4162
# Epoch 87, CIFAR-10 Batch 5:  Loss =>  1.62686  | Accuracy =>  0.4122
# Epoch 88, CIFAR-10 Batch 1:  Loss =>  1.64072  | Accuracy =>  0.4184
# Epoch 88, CIFAR-10 Batch 2:  Loss =>  1.50732  | Accuracy =>  0.417
# Epoch 88, CIFAR-10 Batch 3:  Loss =>  1.4985  | Accuracy =>  0.4192
# Epoch 88, CIFAR-10 Batch 4:  Loss =>  1.4861  | Accuracy =>  0.419
# Epoch 88, CIFAR-10 Batch 5:  Loss =>  1.6201  | Accuracy =>  0.4134
# Epoch 89, CIFAR-10 Batch 1:  Loss =>  1.64634  | Accuracy =>  0.417
# Epoch 89, CIFAR-10 Batch 2:  Loss =>  1.51011  | Accuracy =>  0.4178
# Epoch 89, CIFAR-10 Batch 3:  Loss =>  1.49788  | Accuracy =>  0.4168
# Epoch 89, CIFAR-10 Batch 4:  Loss =>  1.48576  | Accuracy =>  0.4194
# Epoch 89, CIFAR-10 Batch 5:  Loss =>  1.61726  | Accuracy =>  0.4144
# Epoch 90, CIFAR-10 Batch 1:  Loss =>  1.65701  | Accuracy =>  0.4148
# Epoch 90, CIFAR-10 Batch 2:  Loss =>  1.49728  | Accuracy =>  0.4188
# Epoch 90, CIFAR-10 Batch 3:  Loss =>  1.49216  | Accuracy =>  0.4192
# Epoch 90, CIFAR-10 Batch 4:  Loss =>  1.48389  | Accuracy =>  0.4166
# Epoch 90, CIFAR-10 Batch 5:  Loss =>  1.62155  | Accuracy =>  0.4124
# Epoch 91, CIFAR-10 Batch 1:  Loss =>  1.64765  | Accuracy =>  0.417
# Epoch 91, CIFAR-10 Batch 2:  Loss =>  1.50499  | Accuracy =>  0.418
# Epoch 91, CIFAR-10 Batch 3:  Loss =>  1.48118  | Accuracy =>  0.4176
# Epoch 91, CIFAR-10 Batch 4:  Loss =>  1.47998  | Accuracy =>  0.4154
# Epoch 91, CIFAR-10 Batch 5:  Loss =>  1.61369  | Accuracy =>  0.4132
# Epoch 92, CIFAR-10 Batch 1:  Loss =>  1.64371  | Accuracy =>  0.4186
# Epoch 92, CIFAR-10 Batch 2:  Loss =>  1.4995  | Accuracy =>  0.4234
# Epoch 92, CIFAR-10 Batch 3:  Loss =>  1.49002  | Accuracy =>  0.4216
# Epoch 92, CIFAR-10 Batch 4:  Loss =>  1.47734  | Accuracy =>  0.4198
# Epoch 92, CIFAR-10 Batch 5:  Loss =>  1.61645  | Accuracy =>  0.4152
# Epoch 93, CIFAR-10 Batch 1:  Loss =>  1.64797  | Accuracy =>  0.4186
# Epoch 93, CIFAR-10 Batch 2:  Loss =>  1.50125  | Accuracy =>  0.4182
# Epoch 93, CIFAR-10 Batch 3:  Loss =>  1.49097  | Accuracy =>  0.4214
# Epoch 93, CIFAR-10 Batch 4:  Loss =>  1.47629  | Accuracy =>  0.4184
# Epoch 93, CIFAR-10 Batch 5:  Loss =>  1.62176  | Accuracy =>  0.416
# Epoch 94, CIFAR-10 Batch 1:  Loss =>  1.63921  | Accuracy =>  0.4172
# Epoch 94, CIFAR-10 Batch 2:  Loss =>  1.50352  | Accuracy =>  0.4168
# Epoch 94, CIFAR-10 Batch 3:  Loss =>  1.49008  | Accuracy =>  0.423
# Epoch 94, CIFAR-10 Batch 4:  Loss =>  1.48426  | Accuracy =>  0.4192
# Epoch 94, CIFAR-10 Batch 5:  Loss =>  1.62717  | Accuracy =>  0.414
# Epoch 95, CIFAR-10 Batch 1:  Loss =>  1.64428  | Accuracy =>  0.42
# Epoch 95, CIFAR-10 Batch 2:  Loss =>  1.50291  | Accuracy =>  0.4188
# Epoch 95, CIFAR-10 Batch 3:  Loss =>  1.49584  | Accuracy =>  0.422
# Epoch 95, CIFAR-10 Batch 4:  Loss =>  1.47716  | Accuracy =>  0.4194
# Epoch 95, CIFAR-10 Batch 5:  Loss =>  1.61958  | Accuracy =>  0.4156
# Epoch 96, CIFAR-10 Batch 1:  Loss =>  1.64562  | Accuracy =>  0.4214
# Epoch 96, CIFAR-10 Batch 2:  Loss =>  1.50094  | Accuracy =>  0.4164
# Epoch 96, CIFAR-10 Batch 3:  Loss =>  1.48972  | Accuracy =>  0.4212
# Epoch 96, CIFAR-10 Batch 4:  Loss =>  1.47782  | Accuracy =>  0.4184
# Epoch 96, CIFAR-10 Batch 5:  Loss =>  1.61814  | Accuracy =>  0.4134
# Epoch 97, CIFAR-10 Batch 1:  Loss =>  1.64765  | Accuracy =>  0.4206
# Epoch 97, CIFAR-10 Batch 2:  Loss =>  1.49942  | Accuracy =>  0.4174
# Epoch 97, CIFAR-10 Batch 3:  Loss =>  1.48947  | Accuracy =>  0.4202
# Epoch 97, CIFAR-10 Batch 4:  Loss =>  1.47618  | Accuracy =>  0.4198
# Epoch 97, CIFAR-10 Batch 5:  Loss =>  1.61625  | Accuracy =>  0.413
# Epoch 98, CIFAR-10 Batch 1:  Loss =>  1.64174  | Accuracy =>  0.4234
# Epoch 98, CIFAR-10 Batch 2:  Loss =>  1.50039  | Accuracy =>  0.4196
# Epoch 98, CIFAR-10 Batch 3:  Loss =>  1.48813  | Accuracy =>  0.424
# Epoch 98, CIFAR-10 Batch 4:  Loss =>  1.48299  | Accuracy =>  0.418
# Epoch 98, CIFAR-10 Batch 5:  Loss =>  1.61422  | Accuracy =>  0.4142
# Epoch 99, CIFAR-10 Batch 1:  Loss =>  1.65647  | Accuracy =>  0.418
# Epoch 99, CIFAR-10 Batch 2:  Loss =>  1.50342  | Accuracy =>  0.4186
# Epoch 99, CIFAR-10 Batch 3:  Loss =>  1.4836  | Accuracy =>  0.4218
# Epoch 99, CIFAR-10 Batch 4:  Loss =>  1.47463  | Accuracy =>  0.4192
# Epoch 99, CIFAR-10 Batch 5:  Loss =>  1.62486  | Accuracy =>  0.4148
# Epoch 100, CIFAR-10 Batch 1:  Loss =>  1.6417  | Accuracy =>  0.4178
# Epoch 100, CIFAR-10 Batch 2:  Loss =>  1.49934  | Accuracy =>  0.418
# Epoch 100, CIFAR-10 Batch 3:  Loss =>  1.48755  | Accuracy =>  0.4232
# Epoch 100, CIFAR-10 Batch 4:  Loss =>  1.47724  | Accuracy =>  0.4206
# Epoch 100, CIFAR-10 Batch 5:  Loss =>  1.62258  | Accuracy =>  0.4092
# Epoch 101, CIFAR-10 Batch 1:  Loss =>  1.63706  | Accuracy =>  0.4208
# Epoch 101, CIFAR-10 Batch 2:  Loss =>  1.48932  | Accuracy =>  0.4222
# Epoch 101, CIFAR-10 Batch 3:  Loss =>  1.48016  | Accuracy =>  0.4224
# Epoch 101, CIFAR-10 Batch 4:  Loss =>  1.47418  | Accuracy =>  0.416
# Epoch 101, CIFAR-10 Batch 5:  Loss =>  1.61771  | Accuracy =>  0.4132
# Epoch 102, CIFAR-10 Batch 1:  Loss =>  1.64667  | Accuracy =>  0.4218
# Epoch 102, CIFAR-10 Batch 2:  Loss =>  1.4956  | Accuracy =>  0.423
# Epoch 102, CIFAR-10 Batch 3:  Loss =>  1.48328  | Accuracy =>  0.4212
# Epoch 102, CIFAR-10 Batch 4:  Loss =>  1.46672  | Accuracy =>  0.421
# Epoch 102, CIFAR-10 Batch 5:  Loss =>  1.60994  | Accuracy =>  0.4108
# Epoch 103, CIFAR-10 Batch 1:  Loss =>  1.64119  | Accuracy =>  0.422
# Epoch 103, CIFAR-10 Batch 2:  Loss =>  1.49594  | Accuracy =>  0.42
# Epoch 103, CIFAR-10 Batch 3:  Loss =>  1.48029  | Accuracy =>  0.4216
# Epoch 103, CIFAR-10 Batch 4:  Loss =>  1.46975  | Accuracy =>  0.4198
# Epoch 103, CIFAR-10 Batch 5:  Loss =>  1.6134  | Accuracy =>  0.4118
# Epoch 104, CIFAR-10 Batch 1:  Loss =>  1.64226  | Accuracy =>  0.4218
# Epoch 104, CIFAR-10 Batch 2:  Loss =>  1.48575  | Accuracy =>  0.4244
# Epoch 104, CIFAR-10 Batch 3:  Loss =>  1.4821  | Accuracy =>  0.423
# Epoch 104, CIFAR-10 Batch 4:  Loss =>  1.466  | Accuracy =>  0.4198
# Epoch 104, CIFAR-10 Batch 5:  Loss =>  1.61392  | Accuracy =>  0.4172
# Epoch 105, CIFAR-10 Batch 1:  Loss =>  1.64177  | Accuracy =>  0.4214
# Epoch 105, CIFAR-10 Batch 2:  Loss =>  1.49528  | Accuracy =>  0.4156
# Epoch 105, CIFAR-10 Batch 3:  Loss =>  1.47086  | Accuracy =>  0.4276
# Epoch 105, CIFAR-10 Batch 4:  Loss =>  1.47159  | Accuracy =>  0.4188
# Epoch 105, CIFAR-10 Batch 5:  Loss =>  1.61738  | Accuracy =>  0.4182
# Epoch 106, CIFAR-10 Batch 1:  Loss =>  1.63117  | Accuracy =>  0.4242
# Epoch 106, CIFAR-10 Batch 2:  Loss =>  1.49394  | Accuracy =>  0.4192
# Epoch 106, CIFAR-10 Batch 3:  Loss =>  1.47434  | Accuracy =>  0.4238
# Epoch 106, CIFAR-10 Batch 4:  Loss =>  1.46784  | Accuracy =>  0.4226
# Epoch 106, CIFAR-10 Batch 5:  Loss =>  1.60261  | Accuracy =>  0.4166
# Epoch 107, CIFAR-10 Batch 1:  Loss =>  1.64234  | Accuracy =>  0.4268
# Epoch 107, CIFAR-10 Batch 2:  Loss =>  1.48787  | Accuracy =>  0.4218
# Epoch 107, CIFAR-10 Batch 3:  Loss =>  1.48506  | Accuracy =>  0.4262
# Epoch 107, CIFAR-10 Batch 4:  Loss =>  1.46628  | Accuracy =>  0.421
# Epoch 107, CIFAR-10 Batch 5:  Loss =>  1.60782  | Accuracy =>  0.416
# Epoch 108, CIFAR-10 Batch 1:  Loss =>  1.64426  | Accuracy =>  0.4258
# Epoch 108, CIFAR-10 Batch 2:  Loss =>  1.48498  | Accuracy =>  0.4246
# Epoch 108, CIFAR-10 Batch 3:  Loss =>  1.47522  | Accuracy =>  0.4282
# Epoch 108, CIFAR-10 Batch 4:  Loss =>  1.46333  | Accuracy =>  0.4232
# Epoch 108, CIFAR-10 Batch 5:  Loss =>  1.60787  | Accuracy =>  0.4138
# Epoch 109, CIFAR-10 Batch 1:  Loss =>  1.63362  | Accuracy =>  0.4272
# Epoch 109, CIFAR-10 Batch 2:  Loss =>  1.4918  | Accuracy =>  0.4184
# Epoch 109, CIFAR-10 Batch 3:  Loss =>  1.48311  | Accuracy =>  0.4284
# Epoch 109, CIFAR-10 Batch 4:  Loss =>  1.46434  | Accuracy =>  0.4244
# Epoch 109, CIFAR-10 Batch 5:  Loss =>  1.60372  | Accuracy =>  0.4168
# Epoch 110, CIFAR-10 Batch 1:  Loss =>  1.63923  | Accuracy =>  0.4234
# Epoch 110, CIFAR-10 Batch 2:  Loss =>  1.48696  | Accuracy =>  0.4252
# Epoch 110, CIFAR-10 Batch 3:  Loss =>  1.46846  | Accuracy =>  0.4262
# Epoch 110, CIFAR-10 Batch 4:  Loss =>  1.46503  | Accuracy =>  0.4202
# Epoch 110, CIFAR-10 Batch 5:  Loss =>  1.6122  | Accuracy =>  0.414
# Epoch 111, CIFAR-10 Batch 1:  Loss =>  1.63324  | Accuracy =>  0.4254
# Epoch 111, CIFAR-10 Batch 2:  Loss =>  1.49533  | Accuracy =>  0.421
# Epoch 111, CIFAR-10 Batch 3:  Loss =>  1.46478  | Accuracy =>  0.43
# Epoch 111, CIFAR-10 Batch 4:  Loss =>  1.4673  | Accuracy =>  0.4192
# Epoch 111, CIFAR-10 Batch 5:  Loss =>  1.60903  | Accuracy =>  0.4158
# Epoch 112, CIFAR-10 Batch 1:  Loss =>  1.63618  | Accuracy =>  0.4232
# Epoch 112, CIFAR-10 Batch 2:  Loss =>  1.48455  | Accuracy =>  0.4224
# Epoch 112, CIFAR-10 Batch 3:  Loss =>  1.47618  | Accuracy =>  0.429
# Epoch 112, CIFAR-10 Batch 4:  Loss =>  1.46277  | Accuracy =>  0.4238
# Epoch 112, CIFAR-10 Batch 5:  Loss =>  1.60696  | Accuracy =>  0.4124
# Epoch 113, CIFAR-10 Batch 1:  Loss =>  1.63595  | Accuracy =>  0.4234
# Epoch 113, CIFAR-10 Batch 2:  Loss =>  1.48393  | Accuracy =>  0.4238
# Epoch 113, CIFAR-10 Batch 3:  Loss =>  1.47168  | Accuracy =>  0.4278
# Epoch 113, CIFAR-10 Batch 4:  Loss =>  1.46339  | Accuracy =>  0.419
# Epoch 113, CIFAR-10 Batch 5:  Loss =>  1.59958  | Accuracy =>  0.4176
# Epoch 114, CIFAR-10 Batch 1:  Loss =>  1.64025  | Accuracy =>  0.4268
# Epoch 114, CIFAR-10 Batch 2:  Loss =>  1.48231  | Accuracy =>  0.4236
# Epoch 114, CIFAR-10 Batch 3:  Loss =>  1.4595  | Accuracy =>  0.4256
# Epoch 114, CIFAR-10 Batch 4:  Loss =>  1.46107  | Accuracy =>  0.4252
# Epoch 114, CIFAR-10 Batch 5:  Loss =>  1.60194  | Accuracy =>  0.4182
# Epoch 115, CIFAR-10 Batch 1:  Loss =>  1.63714  | Accuracy =>  0.4262
# Epoch 115, CIFAR-10 Batch 2:  Loss =>  1.48592  | Accuracy =>  0.4202
# Epoch 115, CIFAR-10 Batch 3:  Loss =>  1.47246  | Accuracy =>  0.4282
# Epoch 115, CIFAR-10 Batch 4:  Loss =>  1.45716  | Accuracy =>  0.4272
# Epoch 115, CIFAR-10 Batch 5:  Loss =>  1.59552  | Accuracy =>  0.42
# Epoch 116, CIFAR-10 Batch 1:  Loss =>  1.63433  | Accuracy =>  0.4274
# Epoch 116, CIFAR-10 Batch 2:  Loss =>  1.48598  | Accuracy =>  0.4242
# Epoch 116, CIFAR-10 Batch 3:  Loss =>  1.46616  | Accuracy =>  0.4298
# Epoch 116, CIFAR-10 Batch 4:  Loss =>  1.4571  | Accuracy =>  0.4268
# Epoch 116, CIFAR-10 Batch 5:  Loss =>  1.59759  | Accuracy =>  0.4208
# Epoch 117, CIFAR-10 Batch 1:  Loss =>  1.64316  | Accuracy =>  0.4262
# Epoch 117, CIFAR-10 Batch 2:  Loss =>  1.4843  | Accuracy =>  0.4242
# Epoch 117, CIFAR-10 Batch 3:  Loss =>  1.46526  | Accuracy =>  0.4332
# Epoch 117, CIFAR-10 Batch 4:  Loss =>  1.46117  | Accuracy =>  0.4268
# Epoch 117, CIFAR-10 Batch 5:  Loss =>  1.59633  | Accuracy =>  0.4192
# Epoch 118, CIFAR-10 Batch 1:  Loss =>  1.62901  | Accuracy =>  0.4282
# Epoch 118, CIFAR-10 Batch 2:  Loss =>  1.48524  | Accuracy =>  0.4212
# Epoch 118, CIFAR-10 Batch 3:  Loss =>  1.47013  | Accuracy =>  0.4272
# Epoch 118, CIFAR-10 Batch 4:  Loss =>  1.46207  | Accuracy =>  0.4218
# Epoch 118, CIFAR-10 Batch 5:  Loss =>  1.59353  | Accuracy =>  0.4138
# Epoch 119, CIFAR-10 Batch 1:  Loss =>  1.63691  | Accuracy =>  0.427
# Epoch 119, CIFAR-10 Batch 2:  Loss =>  1.47912  | Accuracy =>  0.4278
# Epoch 119, CIFAR-10 Batch 3:  Loss =>  1.45694  | Accuracy =>  0.4266
# Epoch 119, CIFAR-10 Batch 4:  Loss =>  1.46191  | Accuracy =>  0.4288
# Epoch 119, CIFAR-10 Batch 5:  Loss =>  1.6026  | Accuracy =>  0.4188
# Epoch 120, CIFAR-10 Batch 1:  Loss =>  1.62646  | Accuracy =>  0.4294
# Epoch 120, CIFAR-10 Batch 2:  Loss =>  1.47764  | Accuracy =>  0.4248
# Epoch 120, CIFAR-10 Batch 3:  Loss =>  1.4744  | Accuracy =>  0.4286
# Epoch 120, CIFAR-10 Batch 4:  Loss =>  1.46232  | Accuracy =>  0.4214
# Epoch 120, CIFAR-10 Batch 5:  Loss =>  1.59488  | Accuracy =>  0.4174
# Epoch 121, CIFAR-10 Batch 1:  Loss =>  1.63912  | Accuracy =>  0.4276
# Epoch 121, CIFAR-10 Batch 2:  Loss =>  1.48306  | Accuracy =>  0.4268
# Epoch 121, CIFAR-10 Batch 3:  Loss =>  1.46408  | Accuracy =>  0.4252
# Epoch 121, CIFAR-10 Batch 4:  Loss =>  1.4549  | Accuracy =>  0.4234
# Epoch 121, CIFAR-10 Batch 5:  Loss =>  1.60061  | Accuracy =>  0.4194
# Epoch 122, CIFAR-10 Batch 1:  Loss =>  1.63648  | Accuracy =>  0.4252
# Epoch 122, CIFAR-10 Batch 2:  Loss =>  1.476  | Accuracy =>  0.4266
# Epoch 122, CIFAR-10 Batch 3:  Loss =>  1.46573  | Accuracy =>  0.429
# Epoch 122, CIFAR-10 Batch 4:  Loss =>  1.45924  | Accuracy =>  0.4238
# Epoch 122, CIFAR-10 Batch 5:  Loss =>  1.59373  | Accuracy =>  0.4208
# Epoch 123, CIFAR-10 Batch 1:  Loss =>  1.62919  | Accuracy =>  0.4276
# Epoch 123, CIFAR-10 Batch 2:  Loss =>  1.48139  | Accuracy =>  0.4248
# Epoch 123, CIFAR-10 Batch 3:  Loss =>  1.45915  | Accuracy =>  0.431
# Epoch 123, CIFAR-10 Batch 4:  Loss =>  1.45318  | Accuracy =>  0.4232
# Epoch 123, CIFAR-10 Batch 5:  Loss =>  1.59827  | Accuracy =>  0.418
# Epoch 124, CIFAR-10 Batch 1:  Loss =>  1.62641  | Accuracy =>  0.4252
# Epoch 124, CIFAR-10 Batch 2:  Loss =>  1.48523  | Accuracy =>  0.421
# Epoch 124, CIFAR-10 Batch 3:  Loss =>  1.46285  | Accuracy =>  0.4258
# Epoch 124, CIFAR-10 Batch 4:  Loss =>  1.46  | Accuracy =>  0.4274
# Epoch 124, CIFAR-10 Batch 5:  Loss =>  1.59568  | Accuracy =>  0.4244
# Epoch 125, CIFAR-10 Batch 1:  Loss =>  1.62587  | Accuracy =>  0.4284
# Epoch 125, CIFAR-10 Batch 2:  Loss =>  1.47324  | Accuracy =>  0.426
# Epoch 125, CIFAR-10 Batch 3:  Loss =>  1.4577  | Accuracy =>  0.4306
# Epoch 125, CIFAR-10 Batch 4:  Loss =>  1.46021  | Accuracy =>  0.4258
# Epoch 125, CIFAR-10 Batch 5:  Loss =>  1.59314  | Accuracy =>  0.4264
# Epoch 126, CIFAR-10 Batch 1:  Loss =>  1.63301  | Accuracy =>  0.4308
# Epoch 126, CIFAR-10 Batch 2:  Loss =>  1.48179  | Accuracy =>  0.424
# Epoch 126, CIFAR-10 Batch 3:  Loss =>  1.4573  | Accuracy =>  0.4312
# Epoch 126, CIFAR-10 Batch 4:  Loss =>  1.45301  | Accuracy =>  0.425
# Epoch 126, CIFAR-10 Batch 5:  Loss =>  1.59536  | Accuracy =>  0.419
# Epoch 127, CIFAR-10 Batch 1:  Loss =>  1.62583  | Accuracy =>  0.4296
# Epoch 127, CIFAR-10 Batch 2:  Loss =>  1.48069  | Accuracy =>  0.424
# Epoch 127, CIFAR-10 Batch 3:  Loss =>  1.45206  | Accuracy =>  0.4322
# Epoch 127, CIFAR-10 Batch 4:  Loss =>  1.45368  | Accuracy =>  0.429
# Epoch 127, CIFAR-10 Batch 5:  Loss =>  1.59076  | Accuracy =>  0.425
# Epoch 128, CIFAR-10 Batch 1:  Loss =>  1.63669  | Accuracy =>  0.4292
# Epoch 128, CIFAR-10 Batch 2:  Loss =>  1.47623  | Accuracy =>  0.428
# Epoch 128, CIFAR-10 Batch 3:  Loss =>  1.46227  | Accuracy =>  0.4328
# Epoch 128, CIFAR-10 Batch 4:  Loss =>  1.4571  | Accuracy =>  0.4228
# Epoch 128, CIFAR-10 Batch 5:  Loss =>  1.59019  | Accuracy =>  0.4264
# Epoch 129, CIFAR-10 Batch 1:  Loss =>  1.63049  | Accuracy =>  0.4302
# Epoch 129, CIFAR-10 Batch 2:  Loss =>  1.47318  | Accuracy =>  0.4254
# Epoch 129, CIFAR-10 Batch 3:  Loss =>  1.46117  | Accuracy =>  0.4336
# Epoch 129, CIFAR-10 Batch 4:  Loss =>  1.45226  | Accuracy =>  0.4256
# Epoch 129, CIFAR-10 Batch 5:  Loss =>  1.59268  | Accuracy =>  0.4228
# Epoch 130, CIFAR-10 Batch 1:  Loss =>  1.61841  | Accuracy =>  0.4294
# Epoch 130, CIFAR-10 Batch 2:  Loss =>  1.47779  | Accuracy =>  0.4228
# Epoch 130, CIFAR-10 Batch 3:  Loss =>  1.46442  | Accuracy =>  0.4266
# Epoch 130, CIFAR-10 Batch 4:  Loss =>  1.45087  | Accuracy =>  0.4322
# Epoch 130, CIFAR-10 Batch 5:  Loss =>  1.58917  | Accuracy =>  0.4214
# Epoch 131, CIFAR-10 Batch 1:  Loss =>  1.62995  | Accuracy =>  0.4314
# Epoch 131, CIFAR-10 Batch 2:  Loss =>  1.46964  | Accuracy =>  0.426
# Epoch 131, CIFAR-10 Batch 3:  Loss =>  1.45621  | Accuracy =>  0.4318
# Epoch 131, CIFAR-10 Batch 4:  Loss =>  1.45452  | Accuracy =>  0.4324
# Epoch 131, CIFAR-10 Batch 5:  Loss =>  1.59361  | Accuracy =>  0.4206
# Epoch 132, CIFAR-10 Batch 1:  Loss =>  1.62676  | Accuracy =>  0.4272
# Epoch 132, CIFAR-10 Batch 2:  Loss =>  1.47666  | Accuracy =>  0.423
# Epoch 132, CIFAR-10 Batch 3:  Loss =>  1.45845  | Accuracy =>  0.4302
# Epoch 132, CIFAR-10 Batch 4:  Loss =>  1.45346  | Accuracy =>  0.4262
# Epoch 132, CIFAR-10 Batch 5:  Loss =>  1.58839  | Accuracy =>  0.4262
# Epoch 133, CIFAR-10 Batch 1:  Loss =>  1.62304  | Accuracy =>  0.429
# Epoch 133, CIFAR-10 Batch 2:  Loss =>  1.46963  | Accuracy =>  0.4282
# Epoch 133, CIFAR-10 Batch 3:  Loss =>  1.4585  | Accuracy =>  0.4306
# Epoch 133, CIFAR-10 Batch 4:  Loss =>  1.45984  | Accuracy =>  0.429
# Epoch 133, CIFAR-10 Batch 5:  Loss =>  1.58855  | Accuracy =>  0.4246
# Epoch 134, CIFAR-10 Batch 1:  Loss =>  1.63074  | Accuracy =>  0.4282
# Epoch 134, CIFAR-10 Batch 2:  Loss =>  1.47257  | Accuracy =>  0.427
# Epoch 134, CIFAR-10 Batch 3:  Loss =>  1.44718  | Accuracy =>  0.4316
# Epoch 134, CIFAR-10 Batch 4:  Loss =>  1.45854  | Accuracy =>  0.431
# Epoch 134, CIFAR-10 Batch 5:  Loss =>  1.5861  | Accuracy =>  0.424
# Epoch 135, CIFAR-10 Batch 1:  Loss =>  1.62061  | Accuracy =>  0.4298
# Epoch 135, CIFAR-10 Batch 2:  Loss =>  1.47516  | Accuracy =>  0.4254
# Epoch 135, CIFAR-10 Batch 3:  Loss =>  1.45394  | Accuracy =>  0.4336
# Epoch 135, CIFAR-10 Batch 4:  Loss =>  1.45061  | Accuracy =>  0.4274
# Epoch 135, CIFAR-10 Batch 5:  Loss =>  1.58258  | Accuracy =>  0.4244
# Epoch 136, CIFAR-10 Batch 1:  Loss =>  1.6232  | Accuracy =>  0.4298
# Epoch 136, CIFAR-10 Batch 2:  Loss =>  1.46333  | Accuracy =>  0.4296
# Epoch 136, CIFAR-10 Batch 3:  Loss =>  1.45384  | Accuracy =>  0.4342
# Epoch 136, CIFAR-10 Batch 4:  Loss =>  1.44889  | Accuracy =>  0.4322
# Epoch 136, CIFAR-10 Batch 5:  Loss =>  1.58816  | Accuracy =>  0.4254
# Epoch 137, CIFAR-10 Batch 1:  Loss =>  1.62141  | Accuracy =>  0.4308
# Epoch 137, CIFAR-10 Batch 2:  Loss =>  1.47215  | Accuracy =>  0.4282
# Epoch 137, CIFAR-10 Batch 3:  Loss =>  1.45487  | Accuracy =>  0.4318
# Epoch 137, CIFAR-10 Batch 4:  Loss =>  1.45095  | Accuracy =>  0.4344
# Epoch 137, CIFAR-10 Batch 5:  Loss =>  1.58967  | Accuracy =>  0.4222
# Epoch 138, CIFAR-10 Batch 1:  Loss =>  1.63012  | Accuracy =>  0.4284
# Epoch 138, CIFAR-10 Batch 2:  Loss =>  1.46844  | Accuracy =>  0.4328
# Epoch 138, CIFAR-10 Batch 3:  Loss =>  1.45079  | Accuracy =>  0.4304
# Epoch 138, CIFAR-10 Batch 4:  Loss =>  1.45248  | Accuracy =>  0.43
# Epoch 138, CIFAR-10 Batch 5:  Loss =>  1.58482  | Accuracy =>  0.4238
# Epoch 139, CIFAR-10 Batch 1:  Loss =>  1.62388  | Accuracy =>  0.4264
# Epoch 139, CIFAR-10 Batch 2:  Loss =>  1.47325  | Accuracy =>  0.429
# Epoch 139, CIFAR-10 Batch 3:  Loss =>  1.45955  | Accuracy =>  0.4306
# Epoch 139, CIFAR-10 Batch 4:  Loss =>  1.44933  | Accuracy =>  0.4326
# Epoch 139, CIFAR-10 Batch 5:  Loss =>  1.58346  | Accuracy =>  0.4272
# Epoch 140, CIFAR-10 Batch 1:  Loss =>  1.62217  | Accuracy =>  0.4316
# ...
# Epoch 155, CIFAR-10 Batch 2:  Loss =>  1.47739  | Accuracy =>  0.4352
# Epoch 155, CIFAR-10 Batch 3:  Loss =>  1.43066  | Accuracy =>  0.4406
# Epoch 155, CIFAR-10 Batch 4:  Loss =>  1.44077  | Accuracy =>  0.434
# Epoch 155, CIFAR-10 Batch 5:  Loss =>  1.56385  | Accuracy =>  0.4296
# Epoch 156, CIFAR-10 Batch 1:  Loss =>  1.61616  | Accuracy =>  0.439
# Epoch 156, CIFAR-10 Batch 2:  Loss =>  1.46814  | Accuracy =>  0.4368
# Epoch 156, CIFAR-10 Batch 3:  Loss =>  1.43672  | Accuracy =>  0.4386
# Epoch 156, CIFAR-10 Batch 4:  Loss =>  1.44141  | Accuracy =>  0.4372
# Epoch 156, CIFAR-10 Batch 5:  Loss =>  1.57026  | Accuracy =>  0.43
# Epoch 157, CIFAR-10 Batch 1:  Loss =>  1.62427  | Accuracy =>  0.4348
# Epoch 157, CIFAR-10 Batch 2:  Loss =>  1.46722  | Accuracy =>  0.433
# Epoch 157, CIFAR-10 Batch 3:  Loss =>  1.43561  | Accuracy =>  0.4398
# Epoch 157, CIFAR-10 Batch 4:  Loss =>  1.4454  | Accuracy =>  0.4342
# Epoch 157, CIFAR-10 Batch 5:  Loss =>  1.56718  | Accuracy =>  0.4318
# Epoch 158, CIFAR-10 Batch 1:  Loss =>  1.62231  | Accuracy =>  0.4372
# Epoch 158, CIFAR-10 Batch 2:  Loss =>  1.46286  | Accuracy =>  0.4352
# Epoch 158, CIFAR-10 Batch 3:  Loss =>  1.44152  | Accuracy =>  0.435
# Epoch 158, CIFAR-10 Batch 4:  Loss =>  1.4481  | Accuracy =>  0.439
# Epoch 158, CIFAR-10 Batch 5:  Loss =>  1.57244  | Accuracy =>  0.434
# Epoch 159, CIFAR-10 Batch 1:  Loss =>  1.62584  | Accuracy =>  0.4312
# Epoch 159, CIFAR-10 Batch 2:  Loss =>  1.46629  | Accuracy =>  0.437
# Epoch 159, CIFAR-10 Batch 3:  Loss =>  1.43899  | Accuracy =>  0.4382
# Epoch 159, CIFAR-10 Batch 4:  Loss =>  1.44098  | Accuracy =>  0.4346
# Epoch 159, CIFAR-10 Batch 5:  Loss =>  1.56626  | Accuracy =>  0.4362
# Epoch 160, CIFAR-10 Batch 1:  Loss =>  1.61949  | Accuracy =>  0.4356
# Epoch 160, CIFAR-10 Batch 2:  Loss =>  1.46392  | Accuracy =>  0.4412
# Epoch 160, CIFAR-10 Batch 3:  Loss =>  1.43111  | Accuracy =>  0.4392
# Epoch 160, CIFAR-10 Batch 4:  Loss =>  1.44483  | Accuracy =>  0.434
# Epoch 160, CIFAR-10 Batch 5:  Loss =>  1.56748  | Accuracy =>  0.4256
# Epoch 161, CIFAR-10 Batch 1:  Loss =>  1.62075  | Accuracy =>  0.4366
# Epoch 161, CIFAR-10 Batch 2:  Loss =>  1.47153  | Accuracy =>  0.4382
# Epoch 161, CIFAR-10 Batch 3:  Loss =>  1.42831  | Accuracy =>  0.4402
# Epoch 161, CIFAR-10 Batch 4:  Loss =>  1.44436  | Accuracy =>  0.4358
# Epoch 161, CIFAR-10 Batch 5:  Loss =>  1.5734  | Accuracy =>  0.4316
# Epoch 162, CIFAR-10 Batch 1:  Loss =>  1.61855  | Accuracy =>  0.4356
# Epoch 162, CIFAR-10 Batch 2:  Loss =>  1.46617  | Accuracy =>  0.4378
# Epoch 162, CIFAR-10 Batch 3:  Loss =>  1.43337  | Accuracy =>  0.44
# Epoch 162, CIFAR-10 Batch 4:  Loss =>  1.44212  | Accuracy =>  0.4376
# Epoch 162, CIFAR-10 Batch 5:  Loss =>  1.57364  | Accuracy =>  0.432
# Epoch 163, CIFAR-10 Batch 1:  Loss =>  1.61734  | Accuracy =>  0.4334
# Epoch 163, CIFAR-10 Batch 2:  Loss =>  1.46612  | Accuracy =>  0.4362
# Epoch 163, CIFAR-10 Batch 3:  Loss =>  1.43275  | Accuracy =>  0.4396
# Epoch 163, CIFAR-10 Batch 4:  Loss =>  1.44595  | Accuracy =>  0.4364
# Epoch 163, CIFAR-10 Batch 5:  Loss =>  1.56142  | Accuracy =>  0.4358
# Epoch 164, CIFAR-10 Batch 1:  Loss =>  1.63186  | Accuracy =>  0.434
# Epoch 164, CIFAR-10 Batch 2:  Loss =>  1.46756  | Accuracy =>  0.4326
# Epoch 164, CIFAR-10 Batch 3:  Loss =>  1.43633  | Accuracy =>  0.4342
# Epoch 164, CIFAR-10 Batch 4:  Loss =>  1.44419  | Accuracy =>  0.4376
# Epoch 164, CIFAR-10 Batch 5:  Loss =>  1.56244  | Accuracy =>  0.4368
# Epoch 165, CIFAR-10 Batch 1:  Loss =>  1.6231  | Accuracy =>  0.437
# Epoch 165, CIFAR-10 Batch 2:  Loss =>  1.46674  | Accuracy =>  0.4358
# Epoch 165, CIFAR-10 Batch 3:  Loss =>  1.42788  | Accuracy =>  0.4394
# Epoch 165, CIFAR-10 Batch 4:  Loss =>  1.44743  | Accuracy =>  0.433
# Epoch 165, CIFAR-10 Batch 5:  Loss =>  1.56613  | Accuracy =>  0.4356
# Epoch 166, CIFAR-10 Batch 1:  Loss =>  1.6346  | Accuracy =>  0.4318
# Epoch 166, CIFAR-10 Batch 2:  Loss =>  1.46319  | Accuracy =>  0.436
# Epoch 166, CIFAR-10 Batch 3:  Loss =>  1.43776  | Accuracy =>  0.4374
# Epoch 166, CIFAR-10 Batch 4:  Loss =>  1.44534  | Accuracy =>  0.4366
# Epoch 166, CIFAR-10 Batch 5:  Loss =>  1.56102  | Accuracy =>  0.4336
# Epoch 167, CIFAR-10 Batch 1:  Loss =>  1.61952  | Accuracy =>  0.4354
# Epoch 167, CIFAR-10 Batch 2:  Loss =>  1.46478  | Accuracy =>  0.4322
# Epoch 167, CIFAR-10 Batch 3:  Loss =>  1.44194  | Accuracy =>  0.4388
# Epoch 167, CIFAR-10 Batch 4:  Loss =>  1.43627  | Accuracy =>  0.4344
# Epoch 167, CIFAR-10 Batch 5:  Loss =>  1.5698  | Accuracy =>  0.436
# Epoch 168, CIFAR-10 Batch 1:  Loss =>  1.61698  | Accuracy =>  0.4396
# Epoch 168, CIFAR-10 Batch 2:  Loss =>  1.46001  | Accuracy =>  0.4386
# Epoch 168, CIFAR-10 Batch 3:  Loss =>  1.42957  | Accuracy =>  0.4428
# Epoch 168, CIFAR-10 Batch 4:  Loss =>  1.43985  | Accuracy =>  0.4348
# Epoch 168, CIFAR-10 Batch 5:  Loss =>  1.55843  | Accuracy =>  0.4334
# Epoch 169, CIFAR-10 Batch 1:  Loss =>  1.62  | Accuracy =>  0.435
# Epoch 169, CIFAR-10 Batch 2:  Loss =>  1.46351  | Accuracy =>  0.4348
# Epoch 169, CIFAR-10 Batch 3:  Loss =>  1.42772  | Accuracy =>  0.4378
# Epoch 169, CIFAR-10 Batch 4:  Loss =>  1.44083  | Accuracy =>  0.4386
# Epoch 169, CIFAR-10 Batch 5:  Loss =>  1.56154  | Accuracy =>  0.4378
# Epoch 170, CIFAR-10 Batch 1:  Loss =>  1.61284  | Accuracy =>  0.44
# Epoch 170, CIFAR-10 Batch 2:  Loss =>  1.46153  | Accuracy =>  0.4376
# Epoch 170, CIFAR-10 Batch 3:  Loss =>  1.42324  | Accuracy =>  0.4392
# Epoch 170, CIFAR-10 Batch 4:  Loss =>  1.43779  | Accuracy =>  0.4352
# Epoch 170, CIFAR-10 Batch 5:  Loss =>  1.55883  | Accuracy =>  0.4334
# Epoch 171, CIFAR-10 Batch 1:  Loss =>  1.61742  | Accuracy =>  0.4398
# Epoch 171, CIFAR-10 Batch 2:  Loss =>  1.46402  | Accuracy =>  0.4346
# Epoch 171, CIFAR-10 Batch 3:  Loss =>  1.43446  | Accuracy =>  0.4324
# Epoch 171, CIFAR-10 Batch 4:  Loss =>  1.44078  | Accuracy =>  0.438
# Epoch 171, CIFAR-10 Batch 5:  Loss =>  1.55881  | Accuracy =>  0.4358
# Epoch 172, CIFAR-10 Batch 1:  Loss =>  1.62483  | Accuracy =>  0.4324
# Epoch 172, CIFAR-10 Batch 2:  Loss =>  1.46833  | Accuracy =>  0.4342
# Epoch 172, CIFAR-10 Batch 3:  Loss =>  1.429  | Accuracy =>  0.442
# Epoch 172, CIFAR-10 Batch 4:  Loss =>  1.43691  | Accuracy =>  0.4388
# Epoch 172, CIFAR-10 Batch 5:  Loss =>  1.55638  | Accuracy =>  0.4386
# Epoch 173, CIFAR-10 Batch 1:  Loss =>  1.62169  | Accuracy =>  0.4394
# Epoch 173, CIFAR-10 Batch 2:  Loss =>  1.46095  | Accuracy =>  0.4336
# Epoch 173, CIFAR-10 Batch 3:  Loss =>  1.42718  | Accuracy =>  0.4392
# Epoch 173, CIFAR-10 Batch 4:  Loss =>  1.43757  | Accuracy =>  0.4414
# Epoch 173, CIFAR-10 Batch 5:  Loss =>  1.5511  | Accuracy =>  0.4354
# Epoch 174, CIFAR-10 Batch 1:  Loss =>  1.62977  | Accuracy =>  0.4342
# Epoch 174, CIFAR-10 Batch 2:  Loss =>  1.45682  | Accuracy =>  0.4402
# Epoch 174, CIFAR-10 Batch 3:  Loss =>  1.42648  | Accuracy =>  0.441
# Epoch 174, CIFAR-10 Batch 4:  Loss =>  1.44059  | Accuracy =>  0.435
# Epoch 174, CIFAR-10 Batch 5:  Loss =>  1.55052  | Accuracy =>  0.434
# Epoch 175, CIFAR-10 Batch 1:  Loss =>  1.61895  | Accuracy =>  0.437
# Epoch 175, CIFAR-10 Batch 2:  Loss =>  1.45617  | Accuracy =>  0.436
# Epoch 175, CIFAR-10 Batch 3:  Loss =>  1.42754  | Accuracy =>  0.442
# Epoch 175, CIFAR-10 Batch 4:  Loss =>  1.43505  | Accuracy =>  0.4388
# Epoch 175, CIFAR-10 Batch 5:  Loss =>  1.55929  | Accuracy =>  0.4342
# Epoch 176, CIFAR-10 Batch 1:  Loss =>  1.62662  | Accuracy =>  0.4338
# Epoch 176, CIFAR-10 Batch 2:  Loss =>  1.45896  | Accuracy =>  0.4386
# Epoch 176, CIFAR-10 Batch 3:  Loss =>  1.43127  | Accuracy =>  0.4416
# Epoch 176, CIFAR-10 Batch 4:  Loss =>  1.44018  | Accuracy =>  0.4374
# Epoch 176, CIFAR-10 Batch 5:  Loss =>  1.55874  | Accuracy =>  0.4346
# Epoch 177, CIFAR-10 Batch 1:  Loss =>  1.61738  | Accuracy =>  0.4362
# Epoch 177, CIFAR-10 Batch 2:  Loss =>  1.46065  | Accuracy =>  0.435
# Epoch 177, CIFAR-10 Batch 3:  Loss =>  1.42447  | Accuracy =>  0.4422
# Epoch 177, CIFAR-10 Batch 4:  Loss =>  1.43861  | Accuracy =>  0.4392
# Epoch 177, CIFAR-10 Batch 5:  Loss =>  1.55792  | Accuracy =>  0.4342
# Epoch 178, CIFAR-10 Batch 1:  Loss =>  1.61539  | Accuracy =>  0.4422
# Epoch 178, CIFAR-10 Batch 2:  Loss =>  1.45983  | Accuracy =>  0.436
# Epoch 178, CIFAR-10 Batch 3:  Loss =>  1.42318  | Accuracy =>  0.4404
# Epoch 178, CIFAR-10 Batch 4:  Loss =>  1.43065  | Accuracy =>  0.4414
# Epoch 178, CIFAR-10 Batch 5:  Loss =>  1.55356  | Accuracy =>  0.4376
# Epoch 179, CIFAR-10 Batch 1:  Loss =>  1.62039  | Accuracy =>  0.4386
# Epoch 179, CIFAR-10 Batch 2:  Loss =>  1.46485  | Accuracy =>  0.4366
# Epoch 179, CIFAR-10 Batch 3:  Loss =>  1.42887  | Accuracy =>  0.4454
# Epoch 179, CIFAR-10 Batch 4:  Loss =>  1.43503  | Accuracy =>  0.4414
# Epoch 179, CIFAR-10 Batch 5:  Loss =>  1.55627  | Accuracy =>  0.4374
# Epoch 180, CIFAR-10 Batch 1:  Loss =>  1.62529  | Accuracy =>  0.4364
# Epoch 180, CIFAR-10 Batch 2:  Loss =>  1.45831  | Accuracy =>  0.4348
# Epoch 180, CIFAR-10 Batch 3:  Loss =>  1.42347  | Accuracy =>  0.4418
# Epoch 180, CIFAR-10 Batch 4:  Loss =>  1.44451  | Accuracy =>  0.434
# Epoch 180, CIFAR-10 Batch 5:  Loss =>  1.55232  | Accuracy =>  0.4396
# Epoch 181, CIFAR-10 Batch 1:  Loss =>  1.62173  | Accuracy =>  0.4408
# Epoch 181, CIFAR-10 Batch 2:  Loss =>  1.46086  | Accuracy =>  0.435
# Epoch 181, CIFAR-10 Batch 3:  Loss =>  1.42683  | Accuracy =>  0.4378
# Epoch 181, CIFAR-10 Batch 4:  Loss =>  1.43096  | Accuracy =>  0.4394
# Epoch 181, CIFAR-10 Batch 5:  Loss =>  1.55607  | Accuracy =>  0.4374
# Epoch 182, CIFAR-10 Batch 1:  Loss =>  1.61471  | Accuracy =>  0.4394
# Epoch 182, CIFAR-10 Batch 2:  Loss =>  1.46027  | Accuracy =>  0.4354
# Epoch 182, CIFAR-10 Batch 3:  Loss =>  1.42201  | Accuracy =>  0.4384
# Epoch 182, CIFAR-10 Batch 4:  Loss =>  1.435  | Accuracy =>  0.4406
# Epoch 182, CIFAR-10 Batch 5:  Loss =>  1.55461  | Accuracy =>  0.4362
# Epoch 183, CIFAR-10 Batch 1:  Loss =>  1.62565  | Accuracy =>  0.4372
# Epoch 183, CIFAR-10 Batch 2:  Loss =>  1.45394  | Accuracy =>  0.4332
# Epoch 183, CIFAR-10 Batch 3:  Loss =>  1.42094  | Accuracy =>  0.4434
# Epoch 183, CIFAR-10 Batch 4:  Loss =>  1.43604  | Accuracy =>  0.4322
# Epoch 183, CIFAR-10 Batch 5:  Loss =>  1.55088  | Accuracy =>  0.4364
# Epoch 184, CIFAR-10 Batch 1:  Loss =>  1.63042  | Accuracy =>  0.4328
# Epoch 184, CIFAR-10 Batch 2:  Loss =>  1.44898  | Accuracy =>  0.4388
# Epoch 184, CIFAR-10 Batch 3:  Loss =>  1.42534  | Accuracy =>  0.442
# Epoch 184, CIFAR-10 Batch 4:  Loss =>  1.43425  | Accuracy =>  0.438
# Epoch 184, CIFAR-10 Batch 5:  Loss =>  1.55448  | Accuracy =>  0.4378
# Epoch 185, CIFAR-10 Batch 1:  Loss =>  1.61502  | Accuracy =>  0.4378
# Epoch 185, CIFAR-10 Batch 2:  Loss =>  1.4562  | Accuracy =>  0.4364
# Epoch 185, CIFAR-10 Batch 3:  Loss =>  1.43072  | Accuracy =>  0.4398
# Epoch 185, CIFAR-10 Batch 4:  Loss =>  1.42803  | Accuracy =>  0.4392
# Epoch 185, CIFAR-10 Batch 5:  Loss =>  1.56607  | Accuracy =>  0.4346
# Epoch 186, CIFAR-10 Batch 1:  Loss =>  1.61791  | Accuracy =>  0.434
# Epoch 186, CIFAR-10 Batch 2:  Loss =>  1.45421  | Accuracy =>  0.4362
# Epoch 186, CIFAR-10 Batch 3:  Loss =>  1.4238  | Accuracy =>  0.4392
# Epoch 186, CIFAR-10 Batch 4:  Loss =>  1.43519  | Accuracy =>  0.4366
# Epoch 186, CIFAR-10 Batch 5:  Loss =>  1.55973  | Accuracy =>  0.433
# Epoch 187, CIFAR-10 Batch 1:  Loss =>  1.61078  | Accuracy =>  0.438
# Epoch 187, CIFAR-10 Batch 2:  Loss =>  1.45568  | Accuracy =>  0.4354
# Epoch 187, CIFAR-10 Batch 3:  Loss =>  1.41853  | Accuracy =>  0.4428
# Epoch 187, CIFAR-10 Batch 4:  Loss =>  1.42746  | Accuracy =>  0.4406
# Epoch 187, CIFAR-10 Batch 5:  Loss =>  1.55116  | Accuracy =>  0.437
# Epoch 188, CIFAR-10 Batch 1:  Loss =>  1.61497  | Accuracy =>  0.4382
# Epoch 188, CIFAR-10 Batch 2:  Loss =>  1.45811  | Accuracy =>  0.4314
# Epoch 188, CIFAR-10 Batch 3:  Loss =>  1.4165  | Accuracy =>  0.4444
# Epoch 188, CIFAR-10 Batch 4:  Loss =>  1.43271  | Accuracy =>  0.4402
# Epoch 188, CIFAR-10 Batch 5:  Loss =>  1.55764  | Accuracy =>  0.4308
# Epoch 189, CIFAR-10 Batch 1:  Loss =>  1.62041  | Accuracy =>  0.4362
# Epoch 189, CIFAR-10 Batch 2:  Loss =>  1.45757  | Accuracy =>  0.436
# Epoch 189, CIFAR-10 Batch 3:  Loss =>  1.42097  | Accuracy =>  0.4456
# Epoch 189, CIFAR-10 Batch 4:  Loss =>  1.43678  | Accuracy =>  0.4392
# Epoch 189, CIFAR-10 Batch 5:  Loss =>  1.55462  | Accuracy =>  0.4336
# Epoch 190, CIFAR-10 Batch 1:  Loss =>  1.62326  | Accuracy =>  0.4358
# Epoch 190, CIFAR-10 Batch 2:  Loss =>  1.45819  | Accuracy =>  0.441
# Epoch 190, CIFAR-10 Batch 3:  Loss =>  1.43463  | Accuracy =>  0.4382
# Epoch 190, CIFAR-10 Batch 4:  Loss =>  1.43534  | Accuracy =>  0.4384
# Epoch 190, CIFAR-10 Batch 5:  Loss =>  1.55218  | Accuracy =>  0.434
# Epoch 191, CIFAR-10 Batch 1:  Loss =>  1.61668  | Accuracy =>  0.4364
# Epoch 191, CIFAR-10 Batch 2:  Loss =>  1.4535  | Accuracy =>  0.4372
# Epoch 191, CIFAR-10 Batch 3:  Loss =>  1.42568  | Accuracy =>  0.4394
# Epoch 191, CIFAR-10 Batch 4:  Loss =>  1.44388  | Accuracy =>  0.4378
# Epoch 191, CIFAR-10 Batch 5:  Loss =>  1.55218  | Accuracy =>  0.436
# Epoch 192, CIFAR-10 Batch 1:  Loss =>  1.61333  | Accuracy =>  0.4398
# Epoch 192, CIFAR-10 Batch 2:  Loss =>  1.4591  | Accuracy =>  0.4386
# Epoch 192, CIFAR-10 Batch 3:  Loss =>  1.41281  | Accuracy =>  0.4434
# Epoch 192, CIFAR-10 Batch 4:  Loss =>  1.43712  | Accuracy =>  0.437
# Epoch 192, CIFAR-10 Batch 5:  Loss =>  1.55455  | Accuracy =>  0.44
# Epoch 193, CIFAR-10 Batch 1:  Loss =>  1.61745  | Accuracy =>  0.4354
# Epoch 193, CIFAR-10 Batch 2:  Loss =>  1.45177  | Accuracy =>  0.4396
# Epoch 193, CIFAR-10 Batch 3:  Loss =>  1.42452  | Accuracy =>  0.4384
# Epoch 193, CIFAR-10 Batch 4:  Loss =>  1.42729  | Accuracy =>  0.4416
# Epoch 193, CIFAR-10 Batch 5:  Loss =>  1.55272  | Accuracy =>  0.4388
# Epoch 194, CIFAR-10 Batch 1:  Loss =>  1.61598  | Accuracy =>  0.4368
# Epoch 194, CIFAR-10 Batch 2:  Loss =>  1.45361  | Accuracy =>  0.4376
# Epoch 194, CIFAR-10 Batch 3:  Loss =>  1.42295  | Accuracy =>  0.4414
# Epoch 194, CIFAR-10 Batch 4:  Loss =>  1.42936  | Accuracy =>  0.4424
# Epoch 194, CIFAR-10 Batch 5:  Loss =>  1.5495  | Accuracy =>  0.4376
# Epoch 195, CIFAR-10 Batch 1:  Loss =>  1.61974  | Accuracy =>  0.4308
# Epoch 195, CIFAR-10 Batch 2:  Loss =>  1.45673  | Accuracy =>  0.4378
# Epoch 195, CIFAR-10 Batch 3:  Loss =>  1.42395  | Accuracy =>  0.4444
# Epoch 195, CIFAR-10 Batch 4:  Loss =>  1.43187  | Accuracy =>  0.4394
# Epoch 195, CIFAR-10 Batch 5:  Loss =>  1.549  | Accuracy =>  0.4356
# Epoch 196, CIFAR-10 Batch 1:  Loss =>  1.61756  | Accuracy =>  0.4388
# Epoch 196, CIFAR-10 Batch 2:  Loss =>  1.45818  | Accuracy =>  0.44
# Epoch 196, CIFAR-10 Batch 3:  Loss =>  1.41773  | Accuracy =>  0.442
# Epoch 196, CIFAR-10 Batch 4:  Loss =>  1.42845  | Accuracy =>  0.4406
# Epoch 196, CIFAR-10 Batch 5:  Loss =>  1.55251  | Accuracy =>  0.4394
# Epoch 197, CIFAR-10 Batch 1:  Loss =>  1.61658  | Accuracy =>  0.438
# Epoch 197, CIFAR-10 Batch 2:  Loss =>  1.44658  | Accuracy =>  0.437
# Epoch 197, CIFAR-10 Batch 3:  Loss =>  1.42676  | Accuracy =>  0.441
# Epoch 197, CIFAR-10 Batch 4:  Loss =>  1.42745  | Accuracy =>  0.442
# Epoch 197, CIFAR-10 Batch 5:  Loss =>  1.5479  | Accuracy =>  0.4392
# Epoch 198, CIFAR-10 Batch 1:  Loss =>  1.62414  | Accuracy =>  0.4352
# Epoch 198, CIFAR-10 Batch 2:  Loss =>  1.44923  | Accuracy =>  0.4392
# Epoch 198, CIFAR-10 Batch 3:  Loss =>  1.42287  | Accuracy =>  0.4422
# Epoch 198, CIFAR-10 Batch 4:  Loss =>  1.43465  | Accuracy =>  0.4404
# Epoch 198, CIFAR-10 Batch 5:  Loss =>  1.54861  | Accuracy =>  0.4372
# Epoch 199, CIFAR-10 Batch 1:  Loss =>  1.62529  | Accuracy =>  0.4338
# Epoch 199, CIFAR-10 Batch 2:  Loss =>  1.44718  | Accuracy =>  0.4406
# Epoch 199, CIFAR-10 Batch 3:  Loss =>  1.42961  | Accuracy =>  0.4362
# Epoch 199, CIFAR-10 Batch 4:  Loss =>  1.43414  | Accuracy =>  0.4424
# Epoch 199, CIFAR-10 Batch 5:  Loss =>  1.55376  | Accuracy =>  0.439
# Epoch 200, CIFAR-10 Batch 1:  Loss =>  1.61813  | Accuracy =>  0.4368
# Epoch 200, CIFAR-10 Batch 2:  Loss =>  1.46281  | Accuracy =>  0.4396
# Epoch 200, CIFAR-10 Batch 3:  Loss =>  1.41463  | Accuracy =>  0.4414
# Epoch 200, CIFAR-10 Batch 4:  Loss =>  1.42554  | Accuracy =>  0.4424
# Epoch 200, CIFAR-10 Batch 5:  Loss =>  1.55522  | Accuracy =>  0.4372

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.4357996329665184

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
